# %%
import pandas as pd
from IPython.display import display
pd.options.display.max_columns = None

# %%
df = pd.read_csv("/Users/ntinos/Documents/1. Master/1st Term/2 Strategy/Team project/vehicles.csv")
df.head()
# Out:
# /Users/ntinos/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                  vin back_legroom  bed bed_height bed_length        body_type  \
# 0  ZACNJABB5KPJ92081      35.1 in  NaN        NaN        NaN  SUV / Crossover
# 1  SALCJ2FX1LH858117      38.1 in  NaN        NaN        NaN  SUV / Crossover
# 2  JF1VA2M67G9829723      35.4 in  NaN        NaN        NaN            Sedan
# 3  SALRR2RV0L2433391      37.6 in  NaN        NaN        NaN  SUV / Crossover
# 4  SALCJ2FXXLH862327      38.1 in  NaN        NaN        NaN  SUV / Crossover
#
#   cabin      city  city_fuel_economy  combine_fuel_economy  daysonmarket  \
# 0   NaN   Bayamon                NaN                   NaN           522
# 1   NaN  San Juan                NaN                   NaN           207
# ...

# %%
df = df.set_index("vin")
df = df[["price", "back_legroom", "body_type", "city", "daysonmarket", "engine_displacement", "engine_type", "franchise_dealer", "front_legroom", "fuel_tank_volume", "fuel_type", "height", "horsepower", "latitude", "length", "listed_date", "listing_color", "longitude", "major_options", "make_name", "maximum_seating", "mileage", "model_name", "savings_amount", "seller_rating", "torque", "transmission", "wheel_system", "wheelbase", "width", "year"]]
df.head()
# Out:
#                      price back_legroom        body_type      city  \
# vin
# ZACNJABB5KPJ92081  23141.0      35.1 in  SUV / Crossover   Bayamon
# SALCJ2FX1LH858117  46500.0      38.1 in  SUV / Crossover  San Juan
# JF1VA2M67G9829723  46995.0      35.4 in            Sedan  Guaynabo
# SALRR2RV0L2433391  67430.0      37.6 in  SUV / Crossover  San Juan
# SALCJ2FXXLH862327  48880.0      38.1 in  SUV / Crossover  San Juan
#
#                    daysonmarket  engine_displacement engine_type  \
# vin
# ZACNJABB5KPJ92081           522               1300.0          I4
# SALCJ2FX1LH858117           207               2000.0          I4
# JF1VA2M67G9829723          1233               2500.0          H4
# SALRR2RV0L2433391           196               3000.0          V6
# SALCJ2FXXLH862327           137               2000.0          I4
#
#                    franchise_dealer front_legroom fuel_tank_volume fuel_type  \
# vin
# ...

# %%
df.head(60)
# Out:
#                      price back_legroom        body_type       city  \
# vin
# ZACNJABB5KPJ92081  23141.0      35.1 in  SUV / Crossover    Bayamon
# SALCJ2FX1LH858117  46500.0      38.1 in  SUV / Crossover   San Juan
# JF1VA2M67G9829723  46995.0      35.4 in            Sedan   Guaynabo
# SALRR2RV0L2433391  67430.0      37.6 in  SUV / Crossover   San Juan
# SALCJ2FXXLH862327  48880.0      38.1 in  SUV / Crossover   San Juan
# SALYK2EX1LA261711  66903.0      37.1 in  SUV / Crossover   San Juan
# 3MZBPABL6KM107908  23695.0      35.1 in            Sedan    Bayamon
# SALYK2EX5LA275434  68520.0      37.1 in  SUV / Crossover   San Juan
# SALCJ2FX6LH858128  51245.0      38.1 in  SUV / Crossover   San Juan
# SALZL2GX4LH007593  84399.0      33.8 in  SUV / Crossover   San Juan
# ZARBAAC41FM129303  97579.0           --            Coupe   Guaynabo
# SALZJ2FX0LH081763  51885.0      33.8 in  SUV / Crossover   San Juan
# WBA8B7C53GK368522  58995.0      35.1 in            Sedan   Guaynabo
# ...

# %%
df.to_csv("/Users/ntinos/Documents/1. Master/1st Term/2 Strategy/Team project/vehicles_new.csv")
