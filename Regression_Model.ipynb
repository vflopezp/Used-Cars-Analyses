# %%
import pandas as pd
import numpy as np
from scipy import stats
import statsmodels.api as sm



# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# Graph parameters
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False 
plt.rcParams['figure.figsize'] = [14.0,8.0]

# location of data
df = pd.read_csv(r'C:/Users/Hermione/Desktop/MSIN0093 Group Project/vehicles_clean3.csv')
pd.to_datetime(df['listed_date'])
df.info()
vcvtype = 'nonrobust'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500821 entries, 0 to 2500820
# Data columns (total 70 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   Unnamed: 0                        int64
#  1   vin                               object
#  2   price                             float64
#  3   savings_amount                    int64
#  4   make_name                         object
#  5   model_name                        object
#  6   year                              int64
#  7   mileage                           float64
#  8   body_type                         object
#  9   engine_displacement               float64
#  10  engine_type                       object
#  11  horsepower                        float64
#  12  transmission                      object
#  13  wheel_system                      object
#  14  wheelbase                         float64
#  15  fuel_type                         object
# ...

# %%
# Numerical variables:
# 'savings_amount','age','mileage','engine_displacement','horsepower','wheelbase', 'fuel_tank_volume','height',
# 'length','width','back_legroom','front_legroom','major_options_number','maximum_seating','daysonmarket', 
# 'mean_price_by_make_name', 'mean_price_by_model_name'

# %%
df.head()
# Out:
#    Unnamed: 0                vin    price  savings_amount   make_name  \
# 0           0  ZACNJABB5KPJ92081  23141.0               0        Jeep
# 1           1  SALCJ2FX1LH858117  46500.0               0  Land Rover
# 2           2  SALRR2RV0L2433391  67430.0               0  Land Rover
# 3           3  SALCJ2FXXLH862327  48880.0               0  Land Rover
# 4           4  SALYK2EX1LA261711  66903.0               0  Land Rover
#
#           model_name  year  mileage        body_type  engine_displacement  \
# 0           Renegade  2019      7.0  SUV / Crossover               1300.0
# 1    Discovery Sport  2020      8.0  SUV / Crossover               2000.0
# 2          Discovery  2020     11.0  SUV / Crossover               3000.0
# 3    Discovery Sport  2020      7.0  SUV / Crossover               2000.0
# 4  Range Rover Velar  2020     12.0  SUV / Crossover               2000.0
#
#    ... fuel_type_Flex Fuel Vehicle  fuel_type_Gasoline fuel_type_Hybrid  \
# ...

# %%
#One variable

# %%
# X = 'savings_amount'
X = df['savings_amount']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                 1.826e+04
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        04:41:24   Log-Likelihood:            -2.7795e+07
# No. Observations:             2500821   AIC:                         5.559e+07
# Df Residuals:                 2500819   BIC:                         5.559e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           2.959e+04     11.945   2476.901      0.000    2.96e+04    2.96e+04
# ...

# %%
# X = 'age'
X = df['age']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.259
# Model:                            OLS   Adj. R-squared:                  0.259
# Method:                 Least Squares   F-statistic:                 8.745e+05
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        04:42:10   Log-Likelihood:            -2.7429e+07
# No. Observations:             2500821   AIC:                         5.486e+07
# Df Residuals:                 2500819   BIC:                         5.486e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.387e+04     10.421   3250.575      0.000    3.39e+04    3.39e+04
# ...

# %%
# X = 'mileage'
X = df['mileage']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.263
# Model:                            OLS   Adj. R-squared:                  0.263
# Method:                 Least Squares   F-statistic:                 8.934e+05
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        04:42:42   Log-Likelihood:            -2.7422e+07
# No. Observations:             2500821   AIC:                         5.484e+07
# Df Residuals:                 2500819   BIC:                         5.484e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        3.46e+04     10.789   3206.832      0.000    3.46e+04    3.46e+04
# ...

# %%
# X = 'engine_displacement'
X = df['engine_displacement']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.169
# Method:                 Least Squares   F-statistic:                 5.074e+05
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        04:44:05   Log-Likelihood:            -2.7573e+07
# No. Observations:             2500821   AIC:                         5.515e+07
# Df Residuals:                 2500819   BIC:                         5.515e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                1.381e+04     23.004    600.163      0.000    1.38e+04    1.39e+04
# ...

# %%
# X = 'horsepower'
X = df['horsepower']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.393
# Model:                            OLS   Adj. R-squared:                  0.393
# Method:                 Least Squares   F-statistic:                 1.621e+06
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        04:44:43   Log-Likelihood:            -2.7179e+07
# No. Observations:             2500821   AIC:                         5.436e+07
# Df Residuals:                 2500819   BIC:                         5.436e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        289.2495     23.763     12.172      0.000     242.675     335.824
# ...

# %%
# X = 'wheelbase'
X = df['wheelbase']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.210
# Model:                            OLS   Adj. R-squared:                  0.210
# Method:                 Least Squares   F-statistic:                 6.665e+05
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        04:45:12   Log-Likelihood:            -2.7509e+07
# No. Observations:             2500821   AIC:                         5.502e+07
# Df Residuals:                 2500819   BIC:                         5.502e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.255e+04     75.664   -430.231      0.000   -3.27e+04   -3.24e+04
# ...

# %%
# X = 'fuel_tank_volume'
X = df['fuel_tank_volume']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.207
# Model:                            OLS   Adj. R-squared:                  0.207
# Method:                 Least Squares   F-statistic:                 6.527e+05
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        04:46:11   Log-Likelihood:            -2.7514e+07
# No. Observations:             2500821   AIC:                         5.503e+07
# Df Residuals:                 2500819   BIC:                         5.503e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             2529.2358     33.745     74.952      0.000    2463.098    2595.374
# ...

# %%
# X = 'height'
X = df['height']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.177
# Model:                            OLS   Adj. R-squared:                  0.177
# Method:                 Least Squares   F-statistic:                 5.395e+05
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        04:46:41   Log-Likelihood:            -2.7560e+07
# No. Observations:             2500821   AIC:                         5.512e+07
# Df Residuals:                 2500819   BIC:                         5.512e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.578e+04     88.367   -404.894      0.000    -3.6e+04   -3.56e+04
# ...

# %%
# X = 'length'
X = df['length']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.205
# Model:                            OLS   Adj. R-squared:                  0.205
# Method:                 Least Squares   F-statistic:                 6.454e+05
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        04:47:09   Log-Likelihood:            -2.7517e+07
# No. Observations:             2500821   AIC:                         5.503e+07
# Df Residuals:                 2500819   BIC:                         5.503e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.431e+04     91.417   -484.662      0.000   -4.45e+04   -4.41e+04
# ...

# %%
# X = 'width'
X = df['width']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.202
# Model:                            OLS   Adj. R-squared:                  0.202
# Method:                 Least Squares   F-statistic:                 6.314e+05
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        04:47:40   Log-Likelihood:            -2.7522e+07
# No. Observations:             2500821   AIC:                         5.504e+07
# Df Residuals:                 2500819   BIC:                         5.504e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.787e+04     96.876   -494.091      0.000   -4.81e+04   -4.77e+04
# ...

# %%
# X = 'back_legroom'
X = df['back_legroom']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.097
# Method:                 Least Squares   F-statistic:                 2.698e+05
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        04:48:14   Log-Likelihood:            -2.7676e+07
# No. Observations:             2500821   AIC:                         5.535e+07
# Df Residuals:                 2500819   BIC:                         5.535e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -3.236e+04    118.078   -274.044      0.000   -3.26e+04   -3.21e+04
# ...

# %%
# X = 'front_legroom'
X = df['front_legroom']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                 1.463e+04
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        04:48:45   Log-Likelihood:            -2.7797e+07
# No. Observations:             2500821   AIC:                         5.559e+07
# Df Residuals:                 2500819   BIC:                         5.559e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -8160.5426    305.389    -26.722      0.000   -8759.094   -7561.991
# ...

# %%
# X = 'major_options_number'
X = df['major_options_number']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.128
# Method:                 Least Squares   F-statistic:                 3.676e+05
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        04:49:26   Log-Likelihood:            -2.7632e+07
# No. Observations:             2500821   AIC:                         5.526e+07
# Df Residuals:                 2500819   BIC:                         5.526e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 1.953e+04     18.020   1083.606      0.000    1.95e+04    1.96e+04
# ...

# %%
# X = 'maximum_seating'
X = df['maximum_seating']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                 1.267e+05
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        04:50:09   Log-Likelihood:            -2.7742e+07
# No. Observations:             2500821   AIC:                         5.548e+07
# Df Residuals:                 2500819   BIC:                         5.548e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            1.049e+04     52.326    200.426      0.000    1.04e+04    1.06e+04
# ...

# %%
# X = 'daysonmarket'
X = df['daysonmarket']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                 1.260e+04
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        04:50:50   Log-Likelihood:            -2.7798e+07
# No. Observations:             2500821   AIC:                         5.560e+07
# Df Residuals:                 2500819   BIC:                         5.560e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         2.794e+04     12.613   2215.403      0.000    2.79e+04     2.8e+04
# ...

# %%
# X = 'mean_price_by_make_name'
X = df['mean_price_by_make_name']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.207
# Model:                            OLS   Adj. R-squared:                  0.207
# Method:                 Least Squares   F-statistic:                 6.539e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:23:26   Log-Likelihood:            -2.7513e+07
# No. Observations:             2500821   AIC:                         5.503e+07
# Df Residuals:                 2500819   BIC:                         5.503e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.0039     36.734      0.000      1.000     -71.994      72.002
# ...

# %%
# X = 'mean_price_by_model_name'
X = df['mean_price_by_model_name']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.552
# Method:                 Least Squares   F-statistic:                 3.077e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:24:33   Log-Likelihood:            -2.6801e+07
# No. Observations:             2500821   AIC:                         5.360e+07
# Df Residuals:                 2500819   BIC:                         5.360e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.0002     17.790   1.37e-05      1.000     -34.868      34.868
# ...

# %%
#Summary of Single X Variable (R-squared & Adj, R-squared)
# savings_amount = 0.007
# age = 0.259
# mileage = 0.263
# engine_displacement = 0.169
# horsepower = 0.393  
# wheelbase = 0.210
# fuel_tank_volume = 0.207
# height = 0.177
# length = 0.205
# width = 0.202
# back_legroom = 0.097
# fornt_legroom = 0.006
# major_options_number = 0.128
# maximum_seating = 0.048
# daysonmarket = 0.005
# mean_price_by_make_name = 0.207
# mean_price_by_model_name = 0.552   *

#Therefore the best single variable model is the horsepower model
#Now add the second variable to the horsepower model

# %%
#Two Variables

# %%
# X = 'mean_price_by_model_name'  + 'savings_amount'
X = df[['mean_price_by_model_name','savings_amount']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.579
# Model:                            OLS   Adj. R-squared:                  0.579
# Method:                 Least Squares   F-statistic:                 1.719e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:28:53   Log-Likelihood:            -2.6722e+07
# No. Observations:             2500821   AIC:                         5.344e+07
# Df Residuals:                 2500818   BIC:                         5.344e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                      923.2689     17.393     53.084      0.000     889.180     957.358
# ...

# %%
# X = 'mean_price_by_model_name'  + 'age'
X = df[['mean_price_by_model_name','age']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.712
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                 3.084e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:29:29   Log-Likelihood:            -2.6249e+07
# No. Observations:             2500821   AIC:                         5.250e+07
# Df Residuals:                 2500818   BIC:                         5.250e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     6465.8653     15.291    422.866      0.000    6435.896    6495.834
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage'
X = df[['mean_price_by_model_name','mileage']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.729
# Model:                            OLS   Adj. R-squared:                  0.729
# Method:                 Least Squares   F-statistic:                 3.361e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:30:02   Log-Likelihood:            -2.6172e+07
# No. Observations:             2500821   AIC:                         5.234e+07
# Df Residuals:                 2500818   BIC:                         5.234e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     6943.5657     14.864    467.140      0.000    6914.433    6972.699
# ...

# %%
# X = 'mean_price_by_model_name'  + 'engine_displacement'
X = df[['mean_price_by_model_name','engine_displacement']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.552
# Method:                 Least Squares   F-statistic:                 1.541e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:30:30   Log-Likelihood:            -2.6800e+07
# No. Observations:             2500821   AIC:                         5.360e+07
# Df Residuals:                 2500818   BIC:                         5.360e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                      354.8326     19.226     18.456      0.000     317.150     392.515
# ...

# %%
# X = 'mean_price_by_model_name'  + 'horsepower'
X = df[['mean_price_by_model_name','horsepower']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.566
# Model:                            OLS   Adj. R-squared:                  0.566
# Method:                 Least Squares   F-statistic:                 1.629e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:31:20   Log-Likelihood:            -2.6761e+07
# No. Observations:             2500821   AIC:                         5.352e+07
# Df Residuals:                 2500818   BIC:                         5.352e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -2957.8966     20.367   -145.233      0.000   -2997.814   -2917.979
# ...

# %%
# X = 'mean_price_by_model_name'  + 'wheelbase'
X = df[['mean_price_by_model_name','wheelbase']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.553
# Model:                            OLS   Adj. R-squared:                  0.553
# Method:                 Least Squares   F-statistic:                 1.544e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:32:50   Log-Likelihood:            -2.6798e+07
# No. Observations:             2500821   AIC:                         5.360e+07
# Df Residuals:                 2500818   BIC:                         5.360e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -4092.2164     60.563    -67.569      0.000   -4210.919   -3973.514
# ...

# %%
# X = 'mean_price_by_model_name'  + 'fuel_tank_volume'
X = df[['mean_price_by_model_name','fuel_tank_volume']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.552
# Method:                 Least Squares   F-statistic:                 1.543e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:33:24   Log-Likelihood:            -2.6799e+07
# No. Observations:             2500821   AIC:                         5.360e+07
# Df Residuals:                 2500818   BIC:                         5.360e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     1103.7411     25.374     43.498      0.000    1054.008    1153.474
# ...

# %%
# X = 'mean_price_by_model_name'  + 'height'
X = df[['mean_price_by_model_name','height']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.552
# Method:                 Least Squares   F-statistic:                 1.539e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:34:05   Log-Likelihood:            -2.6801e+07
# No. Observations:             2500821   AIC:                         5.360e+07
# Df Residuals:                 2500818   BIC:                         5.360e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -1041.5656     69.525    -14.981      0.000   -1177.833    -905.298
# ...

# %%
# X = 'mean_price_by_model_name'  + 'length'
X = df[['mean_price_by_model_name','length']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.552
# Method:                 Least Squares   F-statistic:                 1.543e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:34:14   Log-Likelihood:            -2.6799e+07
# No. Observations:             2500821   AIC:                         5.360e+07
# Df Residuals:                 2500818   BIC:                         5.360e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -4752.9177     74.241    -64.020      0.000   -4898.427   -4607.408
# ...

# %%
# X = 'mean_price_by_model_name'  + 'width'
X = df[['mean_price_by_model_name','width']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.555
# Method:                 Least Squares   F-statistic:                 1.559e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:34:23   Log-Likelihood:            -2.6792e+07
# No. Observations:             2500821   AIC:                         5.358e+07
# Df Residuals:                 2500818   BIC:                         5.358e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -1.017e+04     77.119   -131.826      0.000   -1.03e+04      -1e+04
# ...

# %%
# X = 'mean_price_by_model_name'  + 'back_legroom'
X = df[['mean_price_by_model_name','back_legroom']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.563
# Model:                            OLS   Adj. R-squared:                  0.563
# Method:                 Least Squares   F-statistic:                 1.608e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:35:14   Log-Likelihood:            -2.6770e+07
# No. Observations:             2500821   AIC:                         5.354e+07
# Df Residuals:                 2500818   BIC:                         5.354e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -2.015e+04     82.538   -244.146      0.000   -2.03e+04      -2e+04
# ...

# %%
# X = 'mean_price_by_model_name'  + 'front_legroom'
X = df[['mean_price_by_model_name','front_legroom']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.554
# Model:                            OLS   Adj. R-squared:                  0.554
# Method:                 Least Squares   F-statistic:                 1.554e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:35:23   Log-Likelihood:            -2.6794e+07
# No. Observations:             2500821   AIC:                         5.359e+07
# Df Residuals:                 2500818   BIC:                         5.359e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     -2.43e+04    204.707   -118.699      0.000   -2.47e+04   -2.39e+04
# ...

# %%
# X = 'mean_price_by_model_name'  + 'major_options_number'
X = df[['mean_price_by_model_name','major_options_number']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.570
# Model:                            OLS   Adj. R-squared:                  0.570
# Method:                 Least Squares   F-statistic:                 1.661e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:35:50   Log-Likelihood:            -2.6747e+07
# No. Observations:             2500821   AIC:                         5.349e+07
# Df Residuals:                 2500818   BIC:                         5.349e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -2006.8828     18.441   -108.828      0.000   -2043.026   -1970.739
# ...

# %%
# X = 'mean_price_by_model_name'  + 'maximum_seating'
X = df[['mean_price_by_model_name','maximum_seating']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.552
# Method:                 Least Squares   F-statistic:                 1.540e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:35:59   Log-Likelihood:            -2.6800e+07
# No. Observations:             2500821   AIC:                         5.360e+07
# Df Residuals:                 2500818   BIC:                         5.360e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     1017.6330     36.347     27.998      0.000     946.395    1088.871
# ...

# %%
# X = 'mean_price_by_model_name'  + 'daysonmarket'
X = df[['mean_price_by_model_name','daysonmarket']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.555
# Method:                 Least Squares   F-statistic:                 1.562e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:36:09   Log-Likelihood:            -2.6790e+07
# No. Observations:             2500821   AIC:                         5.358e+07
# Df Residuals:                 2500818   BIC:                         5.358e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     -675.0443     18.321    -36.846      0.000    -710.953    -639.136
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mean_price_by_make_name'
X = df[['mean_price_by_model_name','mean_price_by_make_name']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.552
# Method:                 Least Squares   F-statistic:                 1.539e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:37:07   Log-Likelihood:            -2.6801e+07
# No. Observations:             2500821   AIC:                         5.360e+07
# Df Residuals:                 2500818   BIC:                         5.360e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        3.5518     27.626      0.129      0.898     -50.594      57.697
# ...

# %%
#Summary of Two X Variable (R-squared & Adj, R-squared)
# mean_price_by_model_name + savings_amount = 0.579
# mean_price_by_model_name + age = 0.712
# mean_price_by_model_name + mileage = 0.729  *
# mean_price_by_model_name + engine_displacement = 0.552     #No increase!
# mean_price_by_model_name + horsepower = 0.566
# mean_price_by_model_name + wheelbase = 0.553
# mean_price_by_model_name + fuel_tank_volume = 0.552        #No increase!
# mean_price_by_model_name + height = 0.552                  #No increase!
# mean_price_by_model_name + length = 0.552                  #No increase!
# mean_price_by_model_name + width = 0.555
# mean_price_by_model_name + back_legroom = 0.563
# mean_price_by_model_name + fornt_legroom = 0.554
# mean_price_by_model_name + major_options_number = 0.570
# mean_price_by_model_name + maximum_seating = 0.552         #No increase!
# mean_price_by_model_name + daysonmarket = 0.555
# mean_price_by_model_name + mean_price_by_make_name = 0.552 #No increase!

#Therefore the best 2-variable model is the 'mean_price_by_model_name + mileage' model
#Now add the third variable to the 'mean_price_by_model_name + mileage'  model

# %%
#Three Varibales

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'savings_amount'
X = df[['mean_price_by_model_name','mileage','savings_amount']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.731
# Model:                            OLS   Adj. R-squared:                  0.731
# Method:                 Least Squares   F-statistic:                 2.260e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:39:22   Log-Likelihood:            -2.6164e+07
# No. Observations:             2500821   AIC:                         5.233e+07
# Df Residuals:                 2500817   BIC:                         5.233e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     6971.6049     14.820    470.434      0.000    6942.559    7000.651
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'age'
X = df[['mean_price_by_model_name','mileage','age']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.734
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                 2.303e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:39:30   Log-Likelihood:            -2.6147e+07
# No. Observations:             2500821   AIC:                         5.229e+07
# Df Residuals:                 2500817   BIC:                         5.229e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     7227.3768     14.769    489.355      0.000    7198.430    7256.324
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'engine_displacement'
X = df[['mean_price_by_model_name','mileage','engine_displacement']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.739
# Model:                            OLS   Adj. R-squared:                  0.739
# Method:                 Least Squares   F-statistic:                 2.360e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:39:40   Log-Likelihood:            -2.6124e+07
# No. Observations:             2500821   AIC:                         5.225e+07
# Df Residuals:                 2500817   BIC:                         5.225e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     5611.4915     15.192    369.361      0.000    5581.715    5641.268
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower'
X = df[['mean_price_by_model_name','mileage','horsepower']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.759
# Model:                            OLS   Adj. R-squared:                  0.759
# Method:                 Least Squares   F-statistic:                 2.630e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:40:40   Log-Likelihood:            -2.6023e+07
# No. Observations:             2500821   AIC:                         5.205e+07
# Df Residuals:                 2500817   BIC:                         5.205e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     2925.4280     15.719    186.102      0.000    2894.618    2956.238
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'wheelbase'
X = df[['mean_price_by_model_name','mileage','wheelbase']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.734
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                 2.296e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:40:52   Log-Likelihood:            -2.6150e+07
# No. Observations:             2500821   AIC:                         5.230e+07
# Df Residuals:                 2500817   BIC:                         5.230e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -2476.1878     46.745    -52.972      0.000   -2567.807   -2384.568
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'fuel_tank_volume'
X = df[['mean_price_by_model_name','mileage','fuel_tank_volume']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.737
# Model:                            OLS   Adj. R-squared:                  0.737
# Method:                 Least Squares   F-statistic:                 2.340e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:41:03   Log-Likelihood:            -2.6132e+07
# No. Observations:             2500821   AIC:                         5.226e+07
# Df Residuals:                 2500817   BIC:                         5.226e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     3267.1403     19.504    167.512      0.000    3228.913    3305.367
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'height'
X = df[['mean_price_by_model_name','mileage','height']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.730
# Model:                            OLS   Adj. R-squared:                  0.730
# Method:                 Least Squares   F-statistic:                 2.255e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:41:38   Log-Likelihood:            -2.6166e+07
# No. Observations:             2500821   AIC:                         5.233e+07
# Df Residuals:                 2500817   BIC:                         5.233e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     1262.3752     53.974     23.388      0.000    1156.587    1368.163
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'length'
X = df[['mean_price_by_model_name','mileage','length']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.735
# Model:                            OLS   Adj. R-squared:                  0.735
# Method:                 Least Squares   F-statistic:                 2.314e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:41:46   Log-Likelihood:            -2.6142e+07
# No. Observations:             2500821   AIC:                         5.228e+07
# Df Residuals:                 2500817   BIC:                         5.229e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -6586.0726     57.124   -115.295      0.000   -6698.033   -6474.112
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'width'
X = df[['mean_price_by_model_name','mileage','width']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                 2.279e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:42:11   Log-Likelihood:            -2.6157e+07
# No. Observations:             2500821   AIC:                         5.231e+07
# Df Residuals:                 2500817   BIC:                         5.231e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -3315.3442     60.063    -55.198      0.000   -3433.066   -3197.623
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'back_legroom'
X = df[['mean_price_by_model_name','mileage','back_legroom']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                 2.280e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:42:40   Log-Likelihood:            -2.6156e+07
# No. Observations:             2500821   AIC:                         5.231e+07
# Df Residuals:                 2500817   BIC:                         5.231e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -4591.5115     65.743    -69.841      0.000   -4720.365   -4462.658
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'front_legroom'
X = df[['mean_price_by_model_name','mileage','front_legroom']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.730
# Model:                            OLS   Adj. R-squared:                  0.730
# Method:                 Least Squares   F-statistic:                 2.257e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:42:46   Log-Likelihood:            -2.6165e+07
# No. Observations:             2500821   AIC:                         5.233e+07
# Df Residuals:                 2500817   BIC:                         5.233e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -1.167e+04    159.525    -73.166      0.000    -1.2e+04   -1.14e+04
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'major_options_number'
X = df[['mean_price_by_model_name','mileage','major_options_number']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.735
# Model:                            OLS   Adj. R-squared:                  0.735
# Method:                 Least Squares   F-statistic:                 2.316e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:42:56   Log-Likelihood:            -2.6142e+07
# No. Observations:             2500821   AIC:                         5.228e+07
# Df Residuals:                 2500817   BIC:                         5.228e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     5569.7498     15.697    354.837      0.000    5538.985    5600.515
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'maximum_seating'
X = df[['mean_price_by_model_name','mileage','maximum_seating']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.730
# Model:                            OLS   Adj. R-squared:                  0.730
# Method:                 Least Squares   F-statistic:                 2.249e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:43:38   Log-Likelihood:            -2.6169e+07
# No. Observations:             2500821   AIC:                         5.234e+07
# Df Residuals:                 2500817   BIC:                         5.234e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     4903.6462     28.396    172.691      0.000    4847.992    4959.300
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'daysonmarket'
X = df[['mean_price_by_model_name','mileage','daysonmarket']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.729
# Model:                            OLS   Adj. R-squared:                  0.729
# Method:                 Least Squares   F-statistic:                 2.244e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:43:46   Log-Likelihood:            -2.6171e+07
# No. Observations:             2500821   AIC:                         5.234e+07
# Df Residuals:                 2500817   BIC:                         5.234e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     6704.6494     15.440    434.243      0.000    6674.388    6734.911
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'mean_price_by_make_name'
X = df[['mean_price_by_model_name','mileage','mean_price_by_make_name']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.729
# Model:                            OLS   Adj. R-squared:                  0.729
# Method:                 Least Squares   F-statistic:                 2.247e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:44:50   Log-Likelihood:            -2.6169e+07
# No. Observations:             2500821   AIC:                         5.234e+07
# Df Residuals:                 2500817   BIC:                         5.234e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     5727.4831     21.920    261.287      0.000    5684.520    5770.446
# ...

# %%
#Summary of Three X Variable (R-squared & Adj, R-squared)
# mean_price_by_model_name + mileage + savings_amount = 0.731
# mean_price_by_model_name + mileage + age = 0.734
# mean_price_by_model_name + mileage + engine_displacement = 0.739
# mean_price_by_model_name + mileage + horsepower = 0.759   *
# mean_price_by_model_name + mileage + wheelbase = 0.734
# mean_price_by_model_name + mileage + fuel_tank_volume = 0.737
# mean_price_by_model_name + mileage + height = 0.730    
# mean_price_by_model_name + mileage + length = 0.735
# mean_price_by_model_name + mileage + width = 0.732
# mean_price_by_model_name + mileage + back_legroom = 0.732
# mean_price_by_model_name + mileage + fornt_legroom = 0.730
# mean_price_by_model_name + mileage + major_options_number = 0.735
# mean_price_by_model_name + mileage + maximum_seating = 0.730
# mean_price_by_model_name + mileage + daysonmarket = 0.729             #No increase!
# mean_price_by_model_name + mileage + mean_price_by_make_name = 0.729  #No increase!

#Therefore the best 3-variable model is the 'mean_price_by_model_name + mileage + horsepower' model
#Now add the fourth variable to the 'mean_price_by_model_name + mileage + horsepower'  model

# %%
#Four Variables

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'savings_amount'
X = df[['mean_price_by_model_name','mileage','horsepower','savings_amount']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.762
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                 2.003e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:45:51   Log-Likelihood:            -2.6008e+07
# No. Observations:             2500821   AIC:                         5.202e+07
# Df Residuals:                 2500816   BIC:                         5.202e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     2874.7556     15.628    183.943      0.000    2844.124    2905.387
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age'
X = df[['mean_price_by_model_name','mileage','horsepower','age']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                 2.039e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:31:37   Log-Likelihood:            -2.5991e+07
# No. Observations:             2500821   AIC:                         5.198e+07
# Df Residuals:                 2500816   BIC:                         5.198e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     3182.8710     15.555    204.626      0.000    3152.385    3213.358
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'engine_displacement'
X = df[['mean_price_by_model_name','mileage','horsepower','engine_displacement']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.761
# Model:                            OLS   Adj. R-squared:                  0.761
# Method:                 Least Squares   F-statistic:                 1.992e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:47:22   Log-Likelihood:            -2.6014e+07
# No. Observations:             2500821   AIC:                         5.203e+07
# Df Residuals:                 2500816   BIC:                         5.203e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     2678.6450     15.762    169.944      0.000    2647.752    2709.538
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'wheelbase'
X = df[['mean_price_by_model_name','mileage','horsepower','wheelbase']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.760
# Method:                 Least Squares   F-statistic:                 1.985e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:48:35   Log-Likelihood:            -2.6017e+07
# No. Observations:             2500821   AIC:                         5.203e+07
# Df Residuals:                 2500816   BIC:                         5.203e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     7979.7272     48.531    164.424      0.000    7884.607    8074.847
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'fuel_tank_volume'
X = df[['mean_price_by_model_name','mileage','horsepower','fuel_tank_volume']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.759
# Model:                            OLS   Adj. R-squared:                  0.759
# Method:                 Least Squares   F-statistic:                 1.974e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:49:15   Log-Likelihood:            -2.6022e+07
# No. Observations:             2500821   AIC:                         5.204e+07
# Df Residuals:                 2500816   BIC:                         5.204e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     3348.8162     18.666    179.412      0.000    3312.232    3385.400
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'height'
X = df[['mean_price_by_model_name','mileage','horsepower','height']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.760
# Method:                 Least Squares   F-statistic:                 1.976e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:50:03   Log-Likelihood:            -2.6021e+07
# No. Observations:             2500821   AIC:                         5.204e+07
# Df Residuals:                 2500816   BIC:                         5.204e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     5866.7949     51.610    113.677      0.000    5765.642    5967.948
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'length'
X = df[['mean_price_by_model_name','mileage','horsepower','length']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.760
# Method:                 Least Squares   F-statistic:                 1.983e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:50:19   Log-Likelihood:            -2.6018e+07
# No. Observations:             2500821   AIC:                         5.204e+07
# Df Residuals:                 2500816   BIC:                         5.204e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     9122.6079     62.410    146.172      0.000    9000.287    9244.929
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'width'
X = df[['mean_price_by_model_name','mileage','horsepower','width']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.760
# Method:                 Least Squares   F-statistic:                 1.978e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:50:40   Log-Likelihood:            -2.6021e+07
# No. Observations:             2500821   AIC:                         5.204e+07
# Df Residuals:                 2500816   BIC:                         5.204e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     7073.3528     60.086    117.720      0.000    6955.586    7191.120
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'back_legroom'
X = df[['mean_price_by_model_name','mileage','horsepower','back_legroom']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.760
# Method:                 Least Squares   F-statistic:                 1.980e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:51:32   Log-Likelihood:            -2.6020e+07
# No. Observations:             2500821   AIC:                         5.204e+07
# Df Residuals:                 2500816   BIC:                         5.204e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -2183.9870     62.411    -34.994      0.000   -2306.310   -2061.664
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'front_legroom'
X = df[['mean_price_by_model_name','mileage','horsepower','front_legroom']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.759
# Model:                            OLS   Adj. R-squared:                  0.759
# Method:                 Least Squares   F-statistic:                 1.972e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:51:52   Log-Likelihood:            -2.6023e+07
# No. Observations:             2500821   AIC:                         5.205e+07
# Df Residuals:                 2500816   BIC:                         5.205e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     3113.5785    153.096     20.337      0.000    2813.517    3413.640
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'major_options_number'
X = df[['mean_price_by_model_name','mileage','horsepower','major_options_number']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.762
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                 1.999e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:52:36   Log-Likelihood:            -2.6010e+07
# No. Observations:             2500821   AIC:                         5.202e+07
# Df Residuals:                 2500816   BIC:                         5.202e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     2281.8410     16.149    141.300      0.000    2250.190    2313.492
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'maximum_seating'
X = df[['mean_price_by_model_name','mileage','horsepower','maximum_seating']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.759
# Model:                            OLS   Adj. R-squared:                  0.759
# Method:                 Least Squares   F-statistic:                 1.974e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:52:53   Log-Likelihood:            -2.6022e+07
# No. Observations:             2500821   AIC:                         5.204e+07
# Df Residuals:                 2500816   BIC:                         5.204e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     3825.1841     26.851    142.459      0.000    3772.557    3877.811
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'daysonmarket'
X = df[['mean_price_by_model_name','mileage','horsepower','daysonmarket']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.760
# Method:                 Least Squares   F-statistic:                 1.979e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:53:37   Log-Likelihood:            -2.6020e+07
# No. Observations:             2500821   AIC:                         5.204e+07
# Df Residuals:                 2500816   BIC:                         5.204e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     2574.8253     16.263    158.324      0.000    2542.950    2606.700
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'mean_price_by_make_name'
X = df[['mean_price_by_model_name','mileage','horsepower','mean_price_by_make_name']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.760
# Method:                 Least Squares   F-statistic:                 1.975e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        12:54:07   Log-Likelihood:            -2.6022e+07
# No. Observations:             2500821   AIC:                         5.204e+07
# Df Residuals:                 2500816   BIC:                         5.204e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     2090.6548     21.658     96.528      0.000    2048.205    2133.105
# ...

# %%
#Summary of Four X Variable (R-squared & Adj, R-squared)
# mean_price_by_model_name + mileage + horsepower + savings_amount = 0.762
# mean_price_by_model_name + mileage + horsepower + age = 0.765                   *
# mean_price_by_model_name + mileage + horsepower + engine_displacement = 0.761
# mean_price_by_model_name + mileage + horsepower + wheelbase = 0.760
# mean_price_by_model_name + mileage + horsepower + fuel_tank_volume = 0.759   #No increase!
# mean_price_by_model_name + mileage + horsepower + height = 0.760    
# mean_price_by_model_name + mileage + horsepower + length = 0.760
# mean_price_by_model_name + mileage + horsepower + width = 0.760
# mean_price_by_model_name + mileage + horsepower + back_legroom = 0.760
# mean_price_by_model_name + mileage + horsepower + fornt_legroom = 0.759     #No increase!
# mean_price_by_model_name + mileage + horsepower + major_options_number = 0.762
# mean_price_by_model_name + mileage + horsepower + maximum_seating = 0.759   #No increase!
# mean_price_by_model_name + mileage + horsepower + daysonmarket = 0.760
# mean_price_by_model_name + mileage + horsepower + mean_price_by_make_name = 0.760

#Therefore the best 4-variable model is the 'mean_price_by_model_name + mileage + horsepower + age' model
#Now add the fifth variable to the 'mean_price_by_model_name + mileage + horsepower + age'  model

# %%
#Five Variables

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                 1.657e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:39:12   Log-Likelihood:            -2.5977e+07
# No. Observations:             2500821   AIC:                         5.195e+07
# Df Residuals:                 2500815   BIC:                         5.195e+07
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     3131.0796     15.465    202.457      0.000    3100.768    3161.391
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'engine_displacement'
X = df[['mean_price_by_model_name','mileage','horsepower','age','engine_displacement']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.767
# Method:                 Least Squares   F-statistic:                 1.643e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:32:55   Log-Likelihood:            -2.5984e+07
# No. Observations:             2500821   AIC:                         5.197e+07
# Df Residuals:                 2500815   BIC:                         5.197e+07
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     2962.7620     15.623    189.644      0.000    2932.142    2993.382
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'wheelbase'
X = df[['mean_price_by_model_name','mileage','horsepower','age','wheelbase']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.767
# Method:                 Least Squares   F-statistic:                 1.645e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:40:50   Log-Likelihood:            -2.5983e+07
# No. Observations:             2500821   AIC:                         5.197e+07
# Df Residuals:                 2500815   BIC:                         5.197e+07
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     9050.6631     48.050    188.358      0.000    8956.486    9144.840
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'fuel_tank_volume'
X = df[['mean_price_by_model_name','mileage','horsepower','age','fuel_tank_volume']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                 1.633e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:41:20   Log-Likelihood:            -2.5990e+07
# No. Observations:             2500821   AIC:                         5.198e+07
# Df Residuals:                 2500815   BIC:                         5.198e+07
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     3616.0477     18.460    195.886      0.000    3579.867    3652.229
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'height'
X = df[['mean_price_by_model_name','mileage','horsepower','age','height']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                 1.638e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:42:01   Log-Likelihood:            -2.5988e+07
# No. Observations:             2500821   AIC:                         5.198e+07
# Df Residuals:                 2500815   BIC:                         5.198e+07
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     7476.8302     51.288    145.783      0.000    7376.308    7577.352
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'length'
X = df[['mean_price_by_model_name','mileage','horsepower','age','length']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.767
# Method:                 Least Squares   F-statistic:                 1.644e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:42:08   Log-Likelihood:            -2.5984e+07
# No. Observations:             2500821   AIC:                         5.197e+07
# Df Residuals:                 2500815   BIC:                         5.197e+07
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     1.041e+04     61.769    168.475      0.000    1.03e+04    1.05e+04
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'width'
X = df[['mean_price_by_model_name','mileage','horsepower','age','width']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                 1.640e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:42:16   Log-Likelihood:            -2.5986e+07
# No. Observations:             2500821   AIC:                         5.197e+07
# Df Residuals:                 2500815   BIC:                         5.197e+07
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     8934.8968     59.693    149.681      0.000    8817.901    9051.893
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'back_legroom'
X = df[['mean_price_by_model_name','mileage','horsepower','age','back_legroom']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                 1.633e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:43:24   Log-Likelihood:            -2.5990e+07
# No. Observations:             2500821   AIC:                         5.198e+07
# Df Residuals:                 2500815   BIC:                         5.198e+07
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                      137.1182     62.411      2.197      0.028      14.795     259.441
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'front_legroom'
X = df[['mean_price_by_model_name','mileage','horsepower','age','front_legroom']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                 1.631e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:43:32   Log-Likelihood:            -2.5991e+07
# No. Observations:             2500821   AIC:                         5.198e+07
# Df Residuals:                 2500815   BIC:                         5.198e+07
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     4962.2901    151.338     32.790      0.000    4665.673    5258.907
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'major_options_number'
X = df[['mean_price_by_model_name','mileage','horsepower','age','major_options_number']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.767
# Method:                 Least Squares   F-statistic:                 1.647e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:44:24   Log-Likelihood:            -2.5982e+07
# No. Observations:             2500821   AIC:                         5.196e+07
# Df Residuals:                 2500815   BIC:                         5.196e+07
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     2622.6038     16.031    163.597      0.000    2591.184    2654.024
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'maximum_seating'
X = df[['mean_price_by_model_name','mileage','horsepower','age','maximum_seating']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                 1.635e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:44:42   Log-Likelihood:            -2.5989e+07
# No. Observations:             2500821   AIC:                         5.198e+07
# Df Residuals:                 2500815   BIC:                         5.198e+07
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     4636.3327     26.682    173.760      0.000    4584.036    4688.629
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'daysonmarket'
X = df[['mean_price_by_model_name','mileage','horsepower','age','daysonmarket']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                 1.635e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:45:34   Log-Likelihood:            -2.5989e+07
# No. Observations:             2500821   AIC:                         5.198e+07
# Df Residuals:                 2500815   BIC:                         5.198e+07
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     2904.9317     16.121    180.191      0.000    2873.334    2936.529
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'mean_price_by_make_name'
X = df[['mean_price_by_model_name','mileage','horsepower','age','mean_price_by_make_name']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                 1.637e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:45:46   Log-Likelihood:            -2.5988e+07
# No. Observations:             2500821   AIC:                         5.198e+07
# Df Residuals:                 2500815   BIC:                         5.198e+07
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     1930.9465     21.377     90.330      0.000    1889.049    1972.844
# ...

# %%
#Summary of Five X Variable (R-squared & Adj, R-squared)
# mean_price_by_model_name + mileage + horsepower + age + savings_amount = 0.768       *
# mean_price_by_model_name + mileage + horsepower + age + engine_displacement = 0.767
# mean_price_by_model_name + mileage + horsepower + age + wheelbase = 0.767
# mean_price_by_model_name + mileage + horsepower + age + fuel_tank_volume = 0.766
# mean_price_by_model_name + mileage + horsepower + age + height = 0.766   
# mean_price_by_model_name + mileage + horsepower + age + length = 0.767
# mean_price_by_model_name + mileage + horsepower + age + width = 0.766
# mean_price_by_model_name + mileage + horsepower + age + back_legroom = 0.766
# mean_price_by_model_name + mileage + horsepower + age + front_legroom = 0.765        #No incarese!
# mean_price_by_model_name + mileage + horsepower + age + major_options_number = 0.767
# mean_price_by_model_name + mileage + horsepower + age + maximum_seating = 0.766
# mean_price_by_model_name + mileage + horsepower + age + daysonmarket = 0.766
# mean_price_by_model_name + mileage + horsepower + age + mean_price_by_make_name = 0.766

#Therefore the best 5-variable model is the 'mean_price_by_model_name + mileage + horsepower + age + savings_amount' model
#Now add the sixth variable to the 'mean_price_by_model_name + mileage + horsepower + age + savings_amount'  model

# %%
#Six Variables

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'engine_displacement'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','engine_displacement']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                 1.392e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:51:43   Log-Likelihood:            -2.5969e+07
# No. Observations:             2500821   AIC:                         5.194e+07
# Df Residuals:                 2500814   BIC:                         5.194e+07
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     2895.4222     15.529    186.457      0.000    2864.987    2925.858
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                 1.394e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:52:58   Log-Likelihood:            -2.5967e+07
# No. Observations:             2500821   AIC:                         5.193e+07
# Df Residuals:                 2500814   BIC:                         5.193e+07
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     9416.6419     47.783    197.069      0.000    9322.988    9510.296
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'fuel_tank_volume'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','fuel_tank_volume']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                 1.382e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:53:37   Log-Likelihood:            -2.5975e+07
# No. Observations:             2500821   AIC:                         5.195e+07
# Df Residuals:                 2500814   BIC:                         5.195e+07
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     3618.1170     18.349    197.187      0.000    3582.154    3654.080
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'height'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','height']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.769
# Method:                 Least Squares   F-statistic:                 1.388e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:54:49   Log-Likelihood:            -2.5971e+07
# No. Observations:             2500821   AIC:                         5.194e+07
# Df Residuals:                 2500814   BIC:                         5.194e+07
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     8109.0809     51.076    158.765      0.000    8008.974    8209.188
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'length'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','length']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                 1.393e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:55:25   Log-Likelihood:            -2.5968e+07
# No. Observations:             2500821   AIC:                         5.194e+07
# Df Residuals:                 2500814   BIC:                         5.194e+07
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     1.098e+04     61.451    178.719      0.000    1.09e+04    1.11e+04
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'width'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','width']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.769
# Method:                 Least Squares   F-statistic:                 1.388e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:56:10   Log-Likelihood:            -2.5971e+07
# No. Observations:             2500821   AIC:                         5.194e+07
# Df Residuals:                 2500814   BIC:                         5.194e+07
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     9019.4952     59.334    152.012      0.000    8903.202    9135.788
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'back_legroom'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','back_legroom']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                 1.382e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:57:12   Log-Likelihood:            -2.5976e+07
# No. Observations:             2500821   AIC:                         5.195e+07
# Df Residuals:                 2500814   BIC:                         5.195e+07
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                      712.0860     62.144     11.459      0.000     590.285     833.887
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'front_legroom'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','front_legroom']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                 1.381e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:57:58   Log-Likelihood:            -2.5977e+07
# No. Observations:             2500821   AIC:                         5.195e+07
# Df Residuals:                 2500814   BIC:                         5.195e+07
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     4235.0334    150.503     28.139      0.000    3940.053    4530.014
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'major_options_number'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','major_options_number']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                 1.397e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:58:35   Log-Likelihood:            -2.5965e+07
# No. Observations:             2500821   AIC:                         5.193e+07
# Df Residuals:                 2500814   BIC:                         5.193e+07
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     2499.3693     15.934    156.856      0.000    2468.139    2530.600
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'maximum_seating'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','maximum_seating']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.769
# Method:                 Least Squares   F-statistic:                 1.384e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        13:59:44   Log-Likelihood:            -2.5974e+07
# No. Observations:             2500821   AIC:                         5.195e+07
# Df Residuals:                 2500814   BIC:                         5.195e+07
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     4725.7185     26.524    178.167      0.000    4673.732    4777.705
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'daysonmarket'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','daysonmarket']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                 1.383e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:02:00   Log-Likelihood:            -2.5975e+07
# No. Observations:             2500821   AIC:                         5.195e+07
# Df Residuals:                 2500814   BIC:                         5.195e+07
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     2908.0386     16.031    181.406      0.000    2876.619    2939.458
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'mean_price_by_make_name'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','mean_price_by_make_name']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.769
# Method:                 Least Squares   F-statistic:                 1.387e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:03:02   Log-Likelihood:            -2.5972e+07
# No. Observations:             2500821   AIC:                         5.194e+07
# Df Residuals:                 2500814   BIC:                         5.194e+07
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     1692.4926     21.281     79.529      0.000    1650.782    1734.203
# ...

# %%
#Summary of Six X Variable (R-squared & Adj, R-squared)
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + engine_displacement = 0.770  *
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase = 0.770            *
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + fuel_tank_volume = 0.768    #No increase!
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + height = 0.769    
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + length = 0.770               *
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + width = 0.769
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + back_legroom = 0.768       #No incarese!
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + front_legroom = 0.768      #No incarese!
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + major_options_number = 0.770
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + maximum_seating = 0.769
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + daysonmarket = 0.768       #No increase!
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + mean_price_by_make_name = 0.769

#Since three models have the same R-sqaured value, compare their RMSE to decide on the best-fitted one
#RMSE of 'mean_price_by_model_name + mileage + horsepower + age + savings_amount + engine_displacement' model = 7825.0294
#RMSE of 'mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase' model = 7819.8432   *
#RMSE of 'mean_price_by_model_name + mileage + horsepower + age + savings_amount + length' model = 7822.7788

#Therefore the best 6-variable model is the 
#'mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase' model
#Now add the seventh variable to the 
#'mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase'  model

# %%
#RMSE of 'mean_price_by_model_name + mileage + horsepower + age + savings_amount + engine_displacement' model
from sklearn.metrics import mean_squared_error
from math import sqrt

df['predicted_6wed'] = 2895.4222 + 0.6544*df['mean_price_by_model_name'] + -0.1080*df['mileage'] + 61.4563*df['horsepower'] 
+ -685.4790*df['age'] + -0.9761*df['savings_amount'] + -0.9129*df['engine_displacement'] 
actual = [df['price']]
predicted1 = [df['predicted_6wed']]

mse_6wed = mean_squared_error(actual, predicted1)
rmse_6wed = rmse = sqrt(mse_6wed)

rmse_6wed
# Out:
# 7825.029397934613

# %%
#RMSE of 'mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase' model
df['predicted_6wwb'] = 9416.6419 + 0.6657*df['mean_price_by_model_name'] + -0.1078*df['mileage'] + 57.6069*df['horsepower'] 
+ -742.6663*df['age'] + -0.9860*df['savings_amount'] + -73.4935*df['wheelbase'] 
actual = [df['price']]
predicted2 = [df['predicted_6wwb']]

mse_6wwb = mean_squared_error(actual, predicted2)
rmse_6wwb = rmse = sqrt(mse_6wwb)

rmse_6wwb
# Out:
# 7819.84319854396

# %%
#RMSE of 'mean_price_by_model_name + mileage + horsepower + age + savings_amount + length' model
df['predicted_6wl'] = 1.098e+04 + 0.6620*df['mean_price_by_model_name'] + -0.1075*df['mileage'] + 58.1101*df['horsepower'] 
+ -740.4654*df['age'] + -0.9892*df['savings_amount'] + -51.9756*df['length'] 
actual = [df['price']]
predicted3 = [df['predicted_6wl']]

mse_6wl = mean_squared_error(actual, predicted3)
rmse_6wl = rmse = sqrt(mse_6wl)

rmse_6wl
# Out:
# 7822.778760962438

# %%
#Since three models have the same R-sqaured value, compare their RMSE to decide on the best-fitted one
#RMSE of 'mean_price_by_model_name + mileage + horsepower + age + savings_amount + engine_displacement' model = 7825.029397934613
#RMSE of 'mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase' model = 7819.84319854396   *

#Therefore the best 6-variable model is the 'mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase' model
#Now add the seventh variable to the 'mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase'  model

# %%
#Seven Variables

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'engine_displacement'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','engine_displacement']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                 1.198e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:17:01   Log-Likelihood:            -2.5964e+07
# No. Observations:             2500821   AIC:                         5.193e+07
# Df Residuals:                 2500813   BIC:                         5.193e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     7640.0685     53.743    142.160      0.000    7534.734    7745.403
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'fuel_tank_volume'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','fuel_tank_volume']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                 1.197e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:20:33   Log-Likelihood:            -2.5965e+07
# No. Observations:             2500821   AIC:                         5.193e+07
# Df Residuals:                 2500813   BIC:                         5.193e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     1.089e+04     54.568    199.553      0.000    1.08e+04     1.1e+04
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'height'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','height']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                 1.196e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:21:43   Log-Likelihood:            -2.5966e+07
# No. Observations:             2500821   AIC:                         5.193e+07
# Df Residuals:                 2500813   BIC:                         5.193e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     1.069e+04     56.820    188.065      0.000    1.06e+04    1.08e+04
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'length'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','length']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                 1.195e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:22:26   Log-Likelihood:            -2.5967e+07
# No. Observations:             2500821   AIC:                         5.193e+07
# Df Residuals:                 2500813   BIC:                         5.193e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     9878.1200     66.254    149.094      0.000    9748.264       1e+04
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'width'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','width']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                 1.198e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:23:07   Log-Likelihood:            -2.5965e+07
# No. Observations:             2500821   AIC:                         5.193e+07
# Df Residuals:                 2500813   BIC:                         5.193e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     1.248e+04     66.445    187.826      0.000    1.23e+04    1.26e+04
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'back_legroom'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','back_legroom']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                 1.199e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:23:59   Log-Likelihood:            -2.5964e+07
# No. Observations:             2500821   AIC:                         5.193e+07
# Df Residuals:                 2500813   BIC:                         5.193e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     5447.8731     68.966     78.993      0.000    5312.702    5583.045
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'front_legroom'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','front_legroom']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                 1.195e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:24:41   Log-Likelihood:            -2.5967e+07
# No. Observations:             2500821   AIC:                         5.193e+07
# Df Residuals:                 2500813   BIC:                         5.193e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     6553.0393    150.824     43.448      0.000    6257.431    6848.648
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'major_options_number'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                 1.207e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:26:08   Log-Likelihood:            -2.5958e+07
# No. Observations:             2500821   AIC:                         5.192e+07
# Df Residuals:                 2500813   BIC:                         5.192e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     8043.7280     48.649    165.343      0.000    7948.378    8139.078
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'maximum_seating'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','maximum_seating']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                 1.198e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:27:17   Log-Likelihood:            -2.5965e+07
# No. Observations:             2500821   AIC:                         5.193e+07
# Df Residuals:                 2500813   BIC:                         5.193e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     1.054e+04     50.959    206.785      0.000    1.04e+04    1.06e+04
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'daysonmarket'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','daysonmarket']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                 1.197e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:28:14   Log-Likelihood:            -2.5966e+07
# No. Observations:             2500821   AIC:                         5.193e+07
# Df Residuals:                 2500813   BIC:                         5.193e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     9145.5448     48.086    190.191      0.000    9051.298    9239.792
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'mean_price_by_make_name'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','mean_price_by_make_name']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.771
# Method:                 Least Squares   F-statistic:                 1.200e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:28:47   Log-Likelihood:            -2.5963e+07
# No. Observations:             2500821   AIC:                         5.193e+07
# Df Residuals:                 2500813   BIC:                         5.193e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     7796.6188     51.279    152.043      0.000    7696.114    7897.124
# ...

# %%
#Summary of Seven X Variable (R-squared & Adj, R-squared)
# mean_price_by_model_name+mileage+horsepower+age+savings_amount+wheelbase+engine_displacement = 0.770  #No increase!
# mean_price_by_model_name+mileage+horsepower+age+savings_amount+wheelbase+fuel_tank_volume = 0.770     #No increase!
# mean_price_by_model_name+mileage+horsepower+age+savings_amount+wheelbase+height = 0.770               #No increase!
# mean_price_by_model_name+mileage+horsepower+age+savings_amount+wheelbase+length = 0.770               #No increase!   
# mean_price_by_model_name+mileage+horsepower+age+savings_amount+wheelbase+width = 0.770                #No increase!   
# mean_price_by_model_name+mileage+horsepower+age+savings_amount+wheelbase+ack_legroom = 0.770         #No increase!    
# mean_price_by_model_name+mileage+horsepower+age+savings_amount+wheelbase+front_legroom = 0.770        #No increase!   
# mean_price_by_model_name+mileage+horsepower+age+savings_amount+wheelbase+major_options_number = 0.772 *
# mean_price_by_model_name+mileage+horsepower+age+savings_amount+wheelbase+maximum_seating = 0.770      #No increase!
# mean_price_by_model_name+mileage+horsepower+age+savings_amount+wheelbase+daysonmarket = 0.770
# mean_price_by_model_name+mileage+horsepower+age+savings_amount+wheelbase+mean_price_by_make_name = 0.771

#Therefore the best 7-variable model is the 
#'mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase + major_options_number' model
#Now add the eighth variable to the 
#'mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase + major_options_number' model

# %%
#Eight Variables

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'major_options_number' + 'engine_displacement'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','engine_displacement']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                 1.059e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:36:27   Log-Likelihood:            -2.5955e+07
# No. Observations:             2500821   AIC:                         5.191e+07
# Df Residuals:                 2500812   BIC:                         5.191e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     6311.7586     54.423    115.975      0.000    6205.091    6418.427
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'major_options_number' + 'fuel_tank_volume'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','fuel_tank_volume']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                 1.057e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:37:55   Log-Likelihood:            -2.5956e+07
# No. Observations:             2500821   AIC:                         5.191e+07
# Df Residuals:                 2500812   BIC:                         5.191e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     9323.9164     55.619    167.640      0.000    9214.906    9432.927
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'major_options_number' + 'height'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','height']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                 1.057e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:39:36   Log-Likelihood:            -2.5956e+07
# No. Observations:             2500821   AIC:                         5.191e+07
# Df Residuals:                 2500812   BIC:                         5.191e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     9505.0078     57.231    166.081      0.000    9392.837    9617.179
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'major_options_number' + 'length'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','length']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                 1.056e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:39:56   Log-Likelihood:            -2.5957e+07
# No. Observations:             2500821   AIC:                         5.191e+07
# Df Residuals:                 2500812   BIC:                         5.191e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     8902.0956     66.382    134.105      0.000    8771.990    9032.201
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'major_options_number' + 'width'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','width']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                 1.058e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:40:40   Log-Likelihood:            -2.5955e+07
# No. Observations:             2500821   AIC:                         5.191e+07
# Df Residuals:                 2500812   BIC:                         5.191e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     1.114e+04     66.904    166.574      0.000     1.1e+04    1.13e+04
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'major_options_number' + 'back_legroom'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','back_legroom']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                 1.059e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:41:31   Log-Likelihood:            -2.5955e+07
# No. Observations:             2500821   AIC:                         5.191e+07
# Df Residuals:                 2500812   BIC:                         5.191e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     4730.4201     68.953     68.603      0.000    4595.274    4865.566
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'major_options_number' + 'front_legroom'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','front_legroom']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                 1.056e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:42:27   Log-Likelihood:            -2.5957e+07
# No. Observations:             2500821   AIC:                         5.191e+07
# Df Residuals:                 2500812   BIC:                         5.191e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     5448.3536    150.480     36.207      0.000    5153.418    5743.289
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'major_options_number' + 'maximum_seating'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','maximum_seating']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                 1.059e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:43:21   Log-Likelihood:            -2.5955e+07
# No. Observations:             2500821   AIC:                         5.191e+07
# Df Residuals:                 2500812   BIC:                         5.191e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     9272.3086     51.542    179.899      0.000    9171.289    9373.329
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'major_options_number' + 'daysonmarket'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','daysonmarket']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                 1.058e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:44:17   Log-Likelihood:            -2.5956e+07
# No. Observations:             2500821   AIC:                         5.191e+07
# Df Residuals:                 2500812   BIC:                         5.191e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     7731.4473     48.976    157.863      0.000    7635.457    7827.438
# ...

# %%
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'major_options_number' + 'mean_price_by_make_name'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','mean_price_by_make_name']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                 1.060e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:44:50   Log-Likelihood:            -2.5954e+07
# No. Observations:             2500821   AIC:                         5.191e+07
# Df Residuals:                 2500812   BIC:                         5.191e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     6493.2836     51.991    124.893      0.000    6391.384    6595.183
# ...

# %%
#Summary of Eight X Variable (R-squared & Adj, R-squared)
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase + major_options_number 
#                          + engine_displacement = 0.772      #No increase!
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase + major_options_number 
#                          + fuel_tank_volume = 0.772         #No increase!
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase + major_options_number 
#                          + height = 0.772                   #No increase!
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase + major_options_number 
#                          + length = 0.772                   #No increase!
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase + major_options_number 
#                          + width = 0.772                    #No increase!
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase + major_options_number 
#                          + back_legroom = 0.772             #No increase!
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase + major_options_number 
#                          + front_legroom = 0.772            #No increase!
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase + major_options_number 
#                          + maximum_seating = 0.772          #No increase!
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase + major_options_number 
#                          + daysonmarket = 0.772             #No increase!
# mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase + major_options_number 
#                          + mean_price_by_make_name = 0.772  #No increase!

#Since no 8-variable model is making any improvment on the best-fitted 7_variable model, the forward selection stops here.
#The best model is the 7-variable model: 
# 'mean_price_by_model_name + mileage + horsepower + age + savings_amount + wheelbase + major_options_number'

# %%
#The "Best" numerical model:
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'major_options_number'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                 1.207e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:49:10   Log-Likelihood:            -2.5958e+07
# No. Observations:             2500821   AIC:                         5.192e+07
# Df Residuals:                 2500813   BIC:                         5.192e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     8043.7280     48.649    165.343      0.000    7948.378    8139.078
# ...

# %%
#Testing each dummy variable first

# %%
# X ='vintage'
X = df['vintage']
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     121.1
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):           3.55e-28
# Time:                        10:27:37   Log-Likelihood:            -2.7804e+07
# No. Observations:             2500821   AIC:                         5.561e+07
# Df Residuals:                 2500819   BIC:                         5.561e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.876e+04     10.308   2790.373      0.000    2.87e+04    2.88e+04
# ...

# %%
# Non-numerical variables:
# 'body_type', 'engine_type','fuel_type','transmission'

# %%
# X ='body_type'(with body_type_Convertible = base)
X = df[['body_type_Coupe','body_type_Hatchback','body_type_Minivan','body_type_Pickup Truck','body_type_SUV / Crossover','body_type_Sedan','body_type_Van','body_type_Wagon']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.153
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                 5.636e+04
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        09:43:26   Log-Likelihood:            -2.7597e+07
# No. Observations:             2500821   AIC:                         5.519e+07
# Df Residuals:                 2500812   BIC:                         5.519e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      3.283e+04    131.321    250.030      0.000    3.26e+04    3.31e+04
# ...

# %%
# X ='engine_type'(with engine_type_H4 = base)
X = df[['engine_type_H6','engine_type_I2','engine_type_I3','engine_type_I4','engine_type_I5','engine_type_I6','engine_type_R2','engine_type_V10','engine_type_V12','engine_type_V6','engine_type_V8','engine_type_W12','engine_type_W8']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.206
# Model:                            OLS   Adj. R-squared:                  0.206
# Method:                 Least Squares   F-statistic:                 5.001e+04
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        09:46:37   Log-Likelihood:            -2.7515e+07
# No. Observations:             2500821   AIC:                         5.503e+07
# Df Residuals:                 2500807   BIC:                         5.503e+07
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            2.474e+04     58.887    420.154      0.000    2.46e+04    2.49e+04
# ...

# %%
# X ='fuel_type'(with fuel_type_Biodiesel = base)
X = df[['fuel_type_Compressed Natural Gas','fuel_type_Diesel','fuel_type_Flex Fuel Vehicle','fuel_type_Gasoline','fuel_type_Hybrid','fuel_type_Propane']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                 1.681e+04
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        09:49:36   Log-Likelihood:            -2.7755e+07
# No. Observations:             2500821   AIC:                         5.551e+07
# Df Residuals:                 2500814   BIC:                         5.551e+07
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# X ='transmission'(with transmission_A = base)
X = df[['transmission_CVT','transmission_Dual Clutch','transmission_M']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                 2.461e+04
# Date:                Mon, 15 Nov 2021   Prob (F-statistic):               0.00
# Time:                        09:51:41   Log-Likelihood:            -2.7768e+07
# No. Observations:             2500821   AIC:                         5.554e+07
# Df Residuals:                 2500817   BIC:                         5.554e+07
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     3.006e+04     11.246   2672.989      0.000       3e+04    3.01e+04
# ...

# %%
#The "Best" numerical model found:
# X = 'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'major_options_number'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                 1.207e+06
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:49:45   Log-Likelihood:            -2.5958e+07
# No. Observations:             2500821   AIC:                         5.192e+07
# Df Residuals:                 2500813   BIC:                         5.192e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     8043.7280     48.649    165.343      0.000    7948.378    8139.078
# ...

# %%
#Add one dummy variable

# %%
# X = Numerical_7 + 'body_type'(with body_type_Convertible = base)
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','body_type_Coupe','body_type_Hatchback','body_type_Minivan','body_type_Pickup Truck','body_type_SUV / Crossover','body_type_Sedan','body_type_Van','body_type_Wagon']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.774
# Model:                            OLS   Adj. R-squared:                  0.774
# Method:                 Least Squares   F-statistic:                 5.715e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:50:26   Log-Likelihood:            -2.5943e+07
# No. Observations:             2500821   AIC:                         5.189e+07
# Df Residuals:                 2500805   BIC:                         5.189e+07
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      2686.5717    118.308     22.708      0.000    2454.692    2918.451
# ...

# %%
# X = Numerical_7 + 'engine_type'(with engine_type_H4 = base)
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','engine_type_H6','engine_type_I2','engine_type_I3','engine_type_I4','engine_type_I5','engine_type_I6','engine_type_R2','engine_type_V10','engine_type_V12','engine_type_V6','engine_type_V8','engine_type_W12','engine_type_W8']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.778
# Model:                            OLS   Adj. R-squared:                  0.778
# Method:                 Least Squares   F-statistic:                 4.373e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:51:52   Log-Likelihood:            -2.5924e+07
# No. Observations:             2500821   AIC:                         5.185e+07
# Df Residuals:                 2500800   BIC:                         5.185e+07
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     8020.5427     65.360    122.713      0.000    7892.439    8148.646
# ...

# %%
# X = Numerical_7 + 'fuel_type'(with fuel_type_Biodiesel = base)
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','fuel_type_Compressed Natural Gas','fuel_type_Diesel','fuel_type_Flex Fuel Vehicle','fuel_type_Gasoline','fuel_type_Hybrid','fuel_type_Propane']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.779
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                 6.765e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:53:18   Log-Likelihood:            -2.5919e+07
# No. Observations:             2500821   AIC:                         5.184e+07
# Df Residuals:                 2500807   BIC:                         5.184e+07
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# X = Numerical_7 + 'transmission'(with transmission_A = base)
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','transmission_CVT','transmission_Dual Clutch','transmission_M']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                 8.453e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:55:01   Log-Likelihood:            -2.5957e+07
# No. Observations:             2500821   AIC:                         5.191e+07
# Df Residuals:                 2500810   BIC:                         5.191e+07
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     7765.9142     49.574    156.653      0.000    7668.751    7863.078
# ...

# %%
#Summary of One Dummy Variable (R-squared & Adj, R-squared)
# Numerical + 'body_type' = 0.774
# Numerical + 'engine_type' = 0.778   
# Numerical + 'fuel_type' = 0.779      *
# Numerical + 'transmission' = 0.772   #No increase!

#Therefore the best one dummy variable model is the Numerical + 'fuel_type' model
#Now add the second dummy variable to the Numerical + 'fuel_type' model

# %%
#Add two dummy variables

# %%
# X = Numerical_7 + 'fuel_type'(with fuel_type_Biodiesel = base) + 'body_type'(with body_type_Convertible = base)
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','fuel_type_Compressed Natural Gas','fuel_type_Diesel','fuel_type_Flex Fuel Vehicle','fuel_type_Gasoline','fuel_type_Hybrid','fuel_type_Propane','body_type_Coupe','body_type_Hatchback','body_type_Minivan','body_type_Pickup Truck','body_type_SUV / Crossover','body_type_Sedan','body_type_Van','body_type_Wagon']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.781
# Model:                            OLS   Adj. R-squared:                  0.781
# Method:                 Least Squares   F-statistic:                 4.238e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:57:54   Log-Likelihood:            -2.5907e+07
# No. Observations:             2500821   AIC:                         5.181e+07
# Df Residuals:                 2500799   BIC:                         5.181e+07
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# X = Numerical_7 + 'fuel_type'(with fuel_type_Biodiesel = base) + 'engine_type'(with engine_type_H4 = base)
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','fuel_type_Compressed Natural Gas','fuel_type_Diesel','fuel_type_Flex Fuel Vehicle','fuel_type_Gasoline','fuel_type_Hybrid','fuel_type_Propane','engine_type_H6','engine_type_I2','engine_type_I3','engine_type_I4','engine_type_I5','engine_type_I6','engine_type_R2','engine_type_V10','engine_type_V12','engine_type_V6','engine_type_V8','engine_type_W12','engine_type_W8']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.783
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                 3.467e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        15:01:08   Log-Likelihood:            -2.5895e+07
# No. Observations:             2500821   AIC:                         5.179e+07
# Df Residuals:                 2500794   BIC:                         5.179e+07
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# X = Numerical_7 + 'fuel_type'(with fuel_type_Biodiesel = base) + 'transmission'(with transmission_A = base)
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','fuel_type_Compressed Natural Gas','fuel_type_Diesel','fuel_type_Flex Fuel Vehicle','fuel_type_Gasoline','fuel_type_Hybrid','fuel_type_Propane','transmission_CVT','transmission_Dual Clutch','transmission_M']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.779
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                 5.498e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        15:03:10   Log-Likelihood:            -2.5918e+07
# No. Observations:             2500821   AIC:                         5.184e+07
# Df Residuals:                 2500804   BIC:                         5.184e+07
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
#Summary of Two Dummy Variable (R-squared & Adj, R-squared)
# Numerical + 'fuel_type' + 'body_type' = 0.781
# Numerical + 'fuel_type' + 'engine_type' = 0.783    *
# Numerical + 'fuel_type' + 'transmission' = 0.779   #No increase!

#Therefore the best two dummy variable model is the Numerical + 'fuel_type' + 'engine_type'model
#Now add the third dummy variable to the Numerical + 'fuel_type' + 'engine_type'model

# %%
#Add three dummy variables

# %%
# X = Numerical_7 + 'fuel_type'(with fuel_type_Biodiesel = base) + 'engine_type'(with engine_type_H4 = base) + 'body_type'(with body_type_Convertible = base)
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','fuel_type_Compressed Natural Gas','fuel_type_Diesel','fuel_type_Flex Fuel Vehicle','fuel_type_Gasoline','fuel_type_Hybrid','fuel_type_Propane','engine_type_H6','engine_type_I2','engine_type_I3','engine_type_I4','engine_type_I5','engine_type_I6','engine_type_R2','engine_type_V10','engine_type_V12','engine_type_V6','engine_type_V8','engine_type_W12','engine_type_W8','body_type_Coupe','body_type_Hatchback','body_type_Minivan','body_type_Pickup Truck','body_type_SUV / Crossover','body_type_Sedan','body_type_Van','body_type_Wagon']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.785
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                 2.678e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        15:05:16   Log-Likelihood:            -2.5885e+07
# No. Observations:             2500821   AIC:                         5.177e+07
# Df Residuals:                 2500786   BIC:                         5.177e+07
# Df Model:                          34
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# X = Numerical_7 + 'engine_type'(with engine_type_H4 = base) + 'fuel_type'(with fuel_type_Biodiesel = base) + 'transmission'(with transmission_A = base)
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','fuel_type_Compressed Natural Gas','fuel_type_Diesel','fuel_type_Flex Fuel Vehicle','fuel_type_Gasoline','fuel_type_Hybrid','fuel_type_Propane','engine_type_H6','engine_type_I2','engine_type_I3','engine_type_I4','engine_type_I5','engine_type_I6','engine_type_R2','engine_type_V10','engine_type_V12','engine_type_V6','engine_type_V8','engine_type_W12','engine_type_W8','transmission_CVT','transmission_Dual Clutch','transmission_M']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.783
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                 3.108e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        15:06:44   Log-Likelihood:            -2.5894e+07
# No. Observations:             2500821   AIC:                         5.179e+07
# Df Residuals:                 2500791   BIC:                         5.179e+07
# Df Model:                          29
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
#Summary of Three Dummy Variable (R-squared & Adj, R-squared)
# Numerical + 'fuel_type' + 'engine_type' + 'body_type' = 0.785     *
# Numerical + 'fuel_type' + 'engine_type' + 'transmission' = 0.783  #No increase!

#Therefore the best three dummy variable model is the Numerical + 'fuel_type' + 'engine_type' + 'body_type' model
#Now add the fourth dummy variable to the Numerical + 'fuel_type' + 'engine_type' + 'body_type' model

# %%
#Add Four Dummy Variables

# %%
# X = Numerical_7 + 'fuel_type'(with fuel_type_Biodiesel = base) + 'engine_type'(with engine_type_H4 = base) + 'body_type'(with body_type_Convertible = base) +'transmission'(with transmission_A = base)
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','fuel_type_Compressed Natural Gas','fuel_type_Diesel','fuel_type_Flex Fuel Vehicle','fuel_type_Gasoline','fuel_type_Hybrid','fuel_type_Propane','engine_type_H6','engine_type_I2','engine_type_I3','engine_type_I4','engine_type_I5','engine_type_I6','engine_type_R2','engine_type_V10','engine_type_V12','engine_type_V6','engine_type_V8','engine_type_W12','engine_type_W8','body_type_Coupe','body_type_Hatchback','body_type_Minivan','body_type_Pickup Truck','body_type_SUV / Crossover','body_type_Sedan','body_type_Van','body_type_Wagon','transmission_CVT','transmission_Dual Clutch','transmission_M']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.785
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                 2.462e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        15:08:50   Log-Likelihood:            -2.5884e+07
# No. Observations:             2500821   AIC:                         5.177e+07
# Df Residuals:                 2500783   BIC:                         5.177e+07
# Df Model:                          37
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
#Summary of Four Dummy Variable (R-squared & Adj, R-squared)
# Numerical + 'fuel_type' + 'engine_type' + 'body_type'+ 'transmission' = 0.785  #No increase!

#Since the four dummy variable model is not improving the three dummy variable model, 
# the best-fitted dummy variable model is the Numerical + 'fuel_type' + 'engine_type'  + 'body_type'model

# %%
#The "Best" Liner Regression Model:
# X = Numerical_7 + 'fuel_type'(with fuel_type_Biodiesel = base) + 'engine_type'(with engine_type_H4 = base) + 'body_type'(with body_type_Convertible = base) +'transmission'(with transmission_A = base)
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','fuel_type_Compressed Natural Gas','fuel_type_Diesel','fuel_type_Flex Fuel Vehicle','fuel_type_Gasoline','fuel_type_Hybrid','fuel_type_Propane','engine_type_H6','engine_type_I2','engine_type_I3','engine_type_I4','engine_type_I5','engine_type_I6','engine_type_R2','engine_type_V10','engine_type_V12','engine_type_V6','engine_type_V8','engine_type_W12','engine_type_W8','body_type_Coupe','body_type_Hatchback','body_type_Minivan','body_type_Pickup Truck','body_type_SUV / Crossover','body_type_Sedan','body_type_Van','body_type_Wagon']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.785
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                 2.678e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        21:53:12   Log-Likelihood:            -2.5885e+07
# No. Observations:             2500821   AIC:                         5.177e+07
# Df Residuals:                 2500786   BIC:                         5.177e+07
# Df Model:                          34
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
#Quadratic and Interaction

# %%
df['age_squared'] = df['age']**2
df['age_int_vintage'] = df['age']*df['vintage']

# %%
# X = Best Linear + age_squared
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','fuel_type_Compressed Natural Gas','fuel_type_Diesel','fuel_type_Flex Fuel Vehicle','fuel_type_Gasoline','fuel_type_Hybrid','fuel_type_Propane','engine_type_H6','engine_type_I2','engine_type_I3','engine_type_I4','engine_type_I5','engine_type_I6','engine_type_R2','engine_type_V10','engine_type_V12','engine_type_V6','engine_type_V8','engine_type_W12','engine_type_W8','body_type_Coupe','body_type_Hatchback','body_type_Minivan','body_type_Pickup Truck','body_type_SUV / Crossover','body_type_Sedan','body_type_Van','body_type_Wagon','age_squared']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.797
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                 2.813e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        21:53:46   Log-Likelihood:            -2.5807e+07
# No. Observations:             2500821   AIC:                         5.161e+07
# Df Residuals:                 2500785   BIC:                         5.162e+07
# Df Model:                          35
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# X = Best Linear + vintage
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','fuel_type_Compressed Natural Gas','fuel_type_Diesel','fuel_type_Flex Fuel Vehicle','fuel_type_Gasoline','fuel_type_Hybrid','fuel_type_Propane','engine_type_H6','engine_type_I2','engine_type_I3','engine_type_I4','engine_type_I5','engine_type_I6','engine_type_R2','engine_type_V10','engine_type_V12','engine_type_V6','engine_type_V8','engine_type_W12','engine_type_W8','body_type_Coupe','body_type_Hatchback','body_type_Minivan','body_type_Pickup Truck','body_type_SUV / Crossover','body_type_Sedan','body_type_Van','body_type_Wagon','vintage']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.785
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                 2.604e+05
# Date:                Thu, 18 Nov 2021   Prob (F-statistic):               0.00
# Time:                        16:10:14   Log-Likelihood:            -2.5884e+07
# No. Observations:             2500821   AIC:                         5.177e+07
# Df Residuals:                 2500785   BIC:                         5.177e+07
# Df Model:                          35
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# X = Best Linear + age_int_vintage
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','fuel_type_Compressed Natural Gas','fuel_type_Diesel','fuel_type_Flex Fuel Vehicle','fuel_type_Gasoline','fuel_type_Hybrid','fuel_type_Propane','engine_type_H6','engine_type_I2','engine_type_I3','engine_type_I4','engine_type_I5','engine_type_I6','engine_type_R2','engine_type_V10','engine_type_V12','engine_type_V6','engine_type_V8','engine_type_W12','engine_type_W8','body_type_Coupe','body_type_Hatchback','body_type_Minivan','body_type_Pickup Truck','body_type_SUV / Crossover','body_type_Sedan','body_type_Van','body_type_Wagon','age_int_vintage']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.785
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                 2.604e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        21:55:08   Log-Likelihood:            -2.5884e+07
# No. Observations:             2500821   AIC:                         5.177e+07
# Df Residuals:                 2500785   BIC:                         5.177e+07
# Df Model:                          35
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# X = Best Linear + age_squared + age_int_vintage
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','fuel_type_Compressed Natural Gas','fuel_type_Diesel','fuel_type_Flex Fuel Vehicle','fuel_type_Gasoline','fuel_type_Hybrid','fuel_type_Propane','engine_type_H6','engine_type_I2','engine_type_I3','engine_type_I4','engine_type_I5','engine_type_I6','engine_type_R2','engine_type_V10','engine_type_V12','engine_type_V6','engine_type_V8','engine_type_W12','engine_type_W8','body_type_Coupe','body_type_Hatchback','body_type_Minivan','body_type_Pickup Truck','body_type_SUV / Crossover','body_type_Sedan','body_type_Van','body_type_Wagon','age_squared','age_int_vintage']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.797
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                 2.736e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        21:55:35   Log-Likelihood:            -2.5807e+07
# No. Observations:             2500821   AIC:                         5.161e+07
# Df Residuals:                 2500784   BIC:                         5.161e+07
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
#Summary for quadratic and interaction varaibles
# Numerical + 'fuel_type' + 'engine_type' + 'body_type'+ 'transmission' + 'age_squared'= 0.797
# Numerical + 'fuel_type' + 'engine_type' + 'body_type'+ 'transmission' + 'age_int_vintage'= 0.785          #No increase!
# Numerical + 'fuel_type' + 'engine_type' + 'body_type'+ 'transmission' + 'age_squared' + 'age_int_vintage'= 0.797 *

# Therefore the best fitted model is:
# Numerical + 'fuel_type' + 'engine_type' + 'body_type'+ 'transmission' + 'age_squared' + 'age_int_vintage'

# %%
#The final model is:
#7-numerical-variables + 3_dummy_variables + 1-quadratic-variable:
#'mean_price_by_model_name'  + 'mileage' + 'horsepower' + 'age' + 'savings_amount' + 'wheelbase' + 'major_options_number' + 'fuel_type'(with fuel_type_Biodiesel = base) + 'engine_type'(with engine_type_H4 = base) + 'body_type'(with body_type_Convertible = base) + 'age_squared' + 'age_int_vintage'
X = df[['mean_price_by_model_name','mileage','horsepower','age','savings_amount','wheelbase','major_options_number','fuel_type_Compressed Natural Gas','fuel_type_Diesel','fuel_type_Flex Fuel Vehicle','fuel_type_Gasoline','fuel_type_Hybrid','fuel_type_Propane','engine_type_H6','engine_type_I2','engine_type_I3','engine_type_I4','engine_type_I5','engine_type_I6','engine_type_R2','engine_type_V10','engine_type_V12','engine_type_V6','engine_type_V8','engine_type_W12','engine_type_W8','body_type_Coupe','body_type_Hatchback','body_type_Minivan','body_type_Pickup Truck','body_type_SUV / Crossover','body_type_Sedan','body_type_Van','body_type_Wagon','age_squared','age_int_vintage']]
X = sm.add_constant(X)
Y = df['price']

# Regression 
model = sm.OLS(Y, X)
results = model.fit(cov_type=vcvtype)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.797
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                 2.736e+05
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        21:55:54   Log-Likelihood:            -2.5807e+07
# No. Observations:             2500821   AIC:                         5.161e+07
# Df Residuals:                 2500784   BIC:                         5.161e+07
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...
