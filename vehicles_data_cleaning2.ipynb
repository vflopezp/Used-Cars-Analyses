# %%
import pandas as pd
from IPython.display import display
pd.options.display.max_columns = None

# %%
df = pd.read_csv("vehicles_new.csv")
df.head()
# Out:
#                  vin    price back_legroom        body_type      city  \
# 0  ZACNJABB5KPJ92081  23141.0      35.1 in  SUV / Crossover   Bayamon
# 1  SALCJ2FX1LH858117  46500.0      38.1 in  SUV / Crossover  San Juan
# 2  JF1VA2M67G9829723  46995.0      35.4 in            Sedan  Guaynabo
# 3  SALRR2RV0L2433391  67430.0      37.6 in  SUV / Crossover  San Juan
# 4  SALCJ2FXXLH862327  48880.0      38.1 in  SUV / Crossover  San Juan
#
#    daysonmarket  engine_displacement engine_type  franchise_dealer  \
# 0           522               1300.0          I4              True
# 1           207               2000.0          I4              True
# 2          1233               2500.0          H4              True
# 3           196               3000.0          V6              True
# 4           137               2000.0          I4              True
#
#   front_legroom fuel_tank_volume fuel_type   height  horsepower  latitude  \
# ...

# %%
df = df.set_index("vin")
df = df[["price", "savings_amount", "make_name", "model_name", "year", "mileage", "body_type", "engine_displacement", "engine_type", "horsepower", "torque", "transmission", "wheel_system", "wheelbase", "fuel_type", "fuel_tank_volume", "height", "length", "width", "back_legroom", "front_legroom", "listing_color",  "major_options", "maximum_seating", "city", "latitude", "longitude", "daysonmarket", "listed_date", "franchise_dealer", "seller_rating"]]
df.head()
# Out:
#                      price  savings_amount   make_name       model_name  year  \
# vin
# ZACNJABB5KPJ92081  23141.0               0        Jeep         Renegade  2019
# SALCJ2FX1LH858117  46500.0               0  Land Rover  Discovery Sport  2020
# JF1VA2M67G9829723  46995.0               0      Subaru          WRX STI  2016
# SALRR2RV0L2433391  67430.0               0  Land Rover        Discovery  2020
# SALCJ2FXXLH862327  48880.0               0  Land Rover  Discovery Sport  2020
#
#                    mileage        body_type  engine_displacement engine_type  \
# vin
# ZACNJABB5KPJ92081      7.0  SUV / Crossover               1300.0          I4
# SALCJ2FX1LH858117      8.0  SUV / Crossover               2000.0          I4
# JF1VA2M67G9829723      NaN            Sedan               2500.0          H4
# SALRR2RV0L2433391     11.0  SUV / Crossover               3000.0          V6
# SALCJ2FXXLH862327      7.0  SUV / Crossover               2000.0          I4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000040 entries, ZACNJABB5KPJ92081 to JN8AT2MT1HW400805
# Data columns (total 31 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   price                float64
#  1   savings_amount       int64
#  2   make_name            object
#  3   model_name           object
#  4   year                 int64
#  5   mileage              float64
#  6   body_type            object
#  7   engine_displacement  float64
#  8   engine_type          object
#  9   horsepower           float64
#  10  torque               object
#  11  transmission         object
#  12  wheel_system         object
#  13  wheelbase            object
#  14  fuel_type            object
#  15  fuel_tank_volume     object
#  16  height               object
#  17  length               object
#  18  width                object
#  19  back_legroom         object
#  20  front_legroom        object
#  21  listing_color        object
# ...

# %%
nanvalues = 0
numbers_floats = 0
others = 0
for i in df['mileage']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == float:
        numbers_floats += 1
    else: 
        others += 1
        
print(nanvalues,numbers_floats,others)
nanvalues/(nanvalues+numbers_floats+others) # 5% missing values for mileage
# Out:
# 144387 2855653 0
# 0.048128358288556154

# %%
df = df[df['mileage'].notna()]

# %%
nanvalues = 0
numbers_floats = 0
others = 0
for i in df['mileage']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == float:
        numbers_floats += 1
    else: 
        others += 1
        
print(nanvalues,numbers_floats,others)
nanvalues/(nanvalues+numbers_floats+others) # 0% missing values for mileage after dropping the rows with NaN
# Out:
# 0 2855653 0
# 0.0

# %%
nanvalues = 0
numbers_floats = 0
others = 0
for i in df['engine_displacement']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == float:
        numbers_floats += 1
    else: 
        others += 1
        
print(nanvalues,numbers_floats,others)
nanvalues/(nanvalues+numbers_floats+others) # 5% missing values for engine displacement
# Out:
# 159952 2695701 0
# 0.05601240766997951

# %%
df = df[df['engine_displacement'].notna()]

# %%
nanvalues = 0
numbers_floats = 0
others = 0
for i in df['engine_displacement']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == float:
        numbers_floats += 1
    else: 
        others += 1
        
print(nanvalues,numbers_floats,others)
nanvalues/(nanvalues+numbers_floats+others) # 0% missing values for engine displacement after droppign the rows with NaN
# Out:
# 0 2695701 0
# 0.0

# %%
nanvalues = 0
numbers_floats = 0
others = 0
for i in df['horsepower']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == float:
        numbers_floats += 1
    else: 
        others += 1
        
print(nanvalues,numbers_floats,others)
nanvalues/(nanvalues+numbers_floats+others) # 0% missing values for horsepower without dropping anything else
# Out:
# 0 2695701 0
# 0.0

# %%
nanvalues = 0
dashes = 0
CVT = 0
A = 0
M = 0
dual = 0
others = 0
for i in df['transmission']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif i == "--":
        dashes+=1
    elif i == "CVT":
        CVT += 1
    elif i == "A":
        A+=1
    elif i == "M":
        M+=1
    elif i == "Dual Clutch":
        dual +=1
    else: 
        others += 1
        
print(nanvalues,dashes,CVT,A,M,dual,others)
nanvalues/(nanvalues+dashes+CVT+A+M+dual+others) # 2% missing values for transmission
# Out:
# 51030 0 423004 2168858 43497 9312 0
# 0.01893014099115592

# %%
df = df[df['transmission'].notna()]

# %%
nanvalues = 0
dashes = 0
CVT = 0
A = 0
M = 0
dual = 0
others = 0
for i in df['transmission']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif i == "--":
        dashes+=1
    elif i == "CVT":
        CVT += 1
    elif i == "A":
        A+=1
    elif i == "M":
        M+=1
    elif i == "Dual Clutch":
        dual +=1
    else: 
        others += 1
        
print(nanvalues,dashes,CVT,A,M,dual,others)
nanvalues/(nanvalues+dashes+CVT+A+M+dual+others) # 0% missing values for transmission after dropping rows with NaN
# Out:
# 0 0 423004 2168858 43497 9312 0
# 0.0

# %%
nanvalues = 0
strings = 0
others = 0
for i in df['wheel_system']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == str:
        strings += 1
    else: 
        others += 1
        
print(nanvalues,strings,others)
nanvalues/(nanvalues+strings+others) # 0.05% missing values for wheel system
# Out:
# 1401 2643270 0
# 0.0005297445315504272

# %%
nanvalues = 0
dashes = 0
FWD = 0
AWD = 0
FourWD = 0
RWD = 0
others = 0
for i in df['wheel_system']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif i == "--":
        dashes+=1
    elif i == "FWD":
        FWD+= 1
    elif i == "AWD":
        AWD+=1
    elif i == "4WD":
        FourWD+=1
    elif i == "RWD":
        RWD+=1
    else: 
        others += 1
        
print(nanvalues,dashes,FWD,AWD,FourWD,RWD,others)
nanvalues/(nanvalues+dashes+FWD+AWD+FourWD+RWD+others) # 0.05% missing values for wheel system
# Out:
# 1401 0 1168089 652423 536447 175681 110630
# 0.0005297445315504272

# %%
df = df[df['wheel_system'].notna()]

# %%
nanvalues = 0
strings = 0
others = 0
for i in df['wheel_system']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == str:
        strings += 1
    else: 
        others += 1
        
print(nanvalues,strings,others)
nanvalues/(nanvalues+strings+others) # 0% missing values for wheel system after dropping rows with NaN
# Out:
# 0 2643270 0
# 0.0

# %%
nanvalues = 0
dashes = 0
strings = 0
others = 0
for i in df['fuel_type']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == str:
        if i == "--":
            dashes+=1
        else:
            strings += 1
    else: 
        others += 1
        
print(nanvalues,dashes,strings,others)
nanvalues/(nanvalues+dashes+strings+others) # 1.1% missing values for fuel_type
# Out:
# 29576 0 2613694 0
# 0.011189170988964426

# %%
df = df[df['fuel_type'].notna()]

# %%
nanvalues = 0
strings = 0
others = 0
for i in df['fuel_type']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == str:
        strings += 1
    else: 
        others += 1
        
print(nanvalues,strings,others)
nanvalues/(nanvalues+strings+others) # 0% missing values for fuel_type after dropping rows with NaN
# Out:
# 0 2613694 0
# 0.0

# %%
nanvalues = 0
dashes = 0
others = 0
for i in df['wheelbase']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif i == "--":
        dashes += 1
    else: 
        others += 1

print(nanvalues,dashes,others)
nanvalues/(nanvalues+dashes+others) # 0.01% of rows have values '--' and 0.1% have NaN so we drop them
# Out:
# 3402 376 2609916
# 0.0013016060793650673

# %%
df = df[df['wheelbase'].notna()]
df = df[df['wheelbase']!="--"]

# %%
len(df.index) # number of remaining observations
# Out:
# 2609916

# %%
arr_of_wheelbase = []
for i in df['wheelbase']:
    wheelbase_without_units = float(i[:i.index(' ')])
    arr_of_wheelbase.append(wheelbase_without_units)

df['wheelbase'] = arr_of_wheelbase
df.head()
# Out:
#                      price  savings_amount   make_name         model_name  \
# vin
# ZACNJABB5KPJ92081  23141.0               0        Jeep           Renegade
# SALCJ2FX1LH858117  46500.0               0  Land Rover    Discovery Sport
# SALRR2RV0L2433391  67430.0               0  Land Rover          Discovery
# SALCJ2FXXLH862327  48880.0               0  Land Rover    Discovery Sport
# SALYK2EX1LA261711  66903.0               0  Land Rover  Range Rover Velar
#
#                    year  mileage        body_type  engine_displacement  \
# vin
# ZACNJABB5KPJ92081  2019      7.0  SUV / Crossover               1300.0
# SALCJ2FX1LH858117  2020      8.0  SUV / Crossover               2000.0
# SALRR2RV0L2433391  2020     11.0  SUV / Crossover               3000.0
# SALCJ2FXXLH862327  2020      7.0  SUV / Crossover               2000.0
# SALYK2EX1LA261711  2020     12.0  SUV / Crossover               2000.0
#
#                   engine_type  horsepower                 torque transmission  \
# ...

# %%
nanvalues = 0
dashes = 0
gals = 0
others = 0
for i in df['fuel_tank_volume']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == str:
        if i[-3:]=='gal':
            gals+=1
        else:
#             print(i)
            dashes += 1
    else: 
        others += 1
        
print(nanvalues,gals,dashes,others)
dashes/(nanvalues+gals+dashes+others) # 0.02% '--' values for fuel_type --> need to drop rows
# Out:
# 0 2609220 696 0
# 0.00026667524931836886

# %%
df = df[df['fuel_tank_volume']!="--"]

# %%
arr_of_ftv = []
for i in df['fuel_tank_volume']:
    ftv_without_units = float(i[:i.index(' ')])
    arr_of_ftv.append(ftv_without_units)  

# print(len(df['fuel_tank_volume']), len(arr_of_ftv))
df['fuel_tank_volume'] = arr_of_ftv

# %%
nanvalues = 0
dashes = 0
ins = 0
others = 0
for i in df['height']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == str:
        if i[-2:]=='in':
            ins+=1
        else:
            print(i)
            dashes += 1
    else: 
        others += 1
        
print(nanvalues,ins,dashes,others)
dashes/(nanvalues+ins+dashes+others) # 0.0004% '--' values for height --> need to drop rows
# Out:
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# 0 2609210 10 0
# 3.83256298817271e-06

# %%
nanvalues = 0
dashes = 0
ins = 0
others = 0
for i in df['length']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == str:
        if i[-2:]=='in':
            ins+=1
        else:
            print(i)
            dashes += 1
    else: 
        others += 1
        
print(nanvalues,ins,dashes,others)
dashes/(nanvalues+ins+dashes+others) # 0.0001% '--' values for length --> need to drop rows
# Out:
# --
# --
# --
# 0 2609217 3 0
# 1.1497688964518131e-06

# %%
nanvalues = 0
dashes = 0
ins = 0
others = 0
for i in df['width']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == str:
        if i[-2:]=='in':
            ins+=1
        else:
            print(i)
            dashes += 1
    else: 
        others += 1
        
print(nanvalues,ins,dashes,others)
dashes/(nanvalues+ins+dashes+others) # 0.0001% '--' values for width --> need to drop rows
# Out:
# --
# --
# --
# 0 2609217 3 0
# 1.1497688964518131e-06

# %%
nanvalues = 0
dashes = 0
ins = 0
others = 0
for i in df['maximum_seating']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == str:
        if i[-5:]=='seats':
            ins+=1
        else:
#             print(i)
            dashes += 1
    else: 
        others += 1
        
print(nanvalues,ins,dashes,others)
dashes/(nanvalues+ins+dashes+others) # 0.0001% '--' values for maximum_seating --> need to drop
# Out:
# 0 2609187 33 0
# 1.2647457860969946e-05

# %%
df = df[df['height']!="--"]
df = df[df['length']!="--"]
df = df[df['width']!="--"]
df = df[df['maximum_seating']!="--"]

# %%
len(df.index) # number of remaining observations
# Out:
# 2609171

# %%
nanvalues = 0
dashes = 0
ins = 0
others = 0
for i in df['back_legroom']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == str:
        if i[-2:]=='in':
            ins+=1
        else:
#             print(i)
            dashes += 1
    else: 
        others += 1
        
print(nanvalues,ins,dashes,others)
dashes/(nanvalues+ins+dashes+others) # 3% '--' values for back_legroom
# Out:
# 0 2534281 74890 0
# 0.028702603240646166

# %%
nanvalues = 0
dashes = 0
ins = 0
others = 0
for i in df['front_legroom']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == str:
        if i[-2:]=='in':
            ins+=1
        else:
#             print(i)
            dashes += 1
    else: 
        others += 1
        
print(nanvalues,ins,dashes,others)
dashes/(nanvalues+ins+dashes+others) # 0.6% '--' values for front_legroom
# Out:
# 0 2594651 14520 0
# 0.005564985966807082

# %%
df = df[df['back_legroom']!="--"]
df = df[df['front_legroom']!="--"]
len(df.index) # number of remaining observations
# Out:
# 2534281

# %%
arr_of_height = []
for i in df['height']:
    height_without_units = float(i[:i.index(' ')])
    arr_of_height.append(height_without_units)  

df['height'] = arr_of_height

# %%
arr_of_length = []
for i in df['length']:
    length_without_units = float(i[:i.index(' ')])
    arr_of_length.append(length_without_units)  

df['length'] = arr_of_length

# %%
arr_of_width = []
for i in df['width']:
    width_without_units = float(i[:i.index(' ')])
    arr_of_width.append(width_without_units)  

df['width'] = arr_of_width

# %%
arr_of_back_legroom = []
for i in df['back_legroom']:
    back_legroom_without_units = float(i[:i.index(' ')])
    arr_of_back_legroom.append(back_legroom_without_units)  

df['back_legroom'] = arr_of_back_legroom

# %%
arr_of_front_legroom = []
for i in df['front_legroom']:
    front_legroom_without_units = float(i[:i.index(' ')])
    arr_of_front_legroom.append(front_legroom_without_units)  

df['front_legroom'] = arr_of_front_legroom

# %%
arr_of_maximum_seating = []
for i in df['maximum_seating']:
    maximum_seating_without_units = float(i[:i.index(' ')])
    arr_of_maximum_seating.append(maximum_seating_without_units)  

df['maximum_seating'] = arr_of_maximum_seating

# %%
arr_of_major_options_number = []
for i in df['major_options']:
    if pd.notna(i):
        arr_of_major_options_number.append(len(i[1:-1].split(",")))
    else: 
        arr_of_major_options_number.append(0)

df['major_options_number'] = arr_of_major_options_number

# %%
nanvalues = 0
RPMs = 0
strings = 0
others = 0
for i in df['torque']:
    if pd.isna(i) == True:
        nanvalues += 1
    elif type(i) == str:
        if i[-3:]=="RPM":
            RPMs+=1
        else:
            print(i)
            strings += 1
    else: 
        others += 1
        
print(nanvalues,RPMs,strings,others)
nanvalues/(nanvalues+RPMs+strings+others) # 12% missing values for torque
# Out:
# 174 lb-ft
# 308989 2225291 1 0
# 0.12192373300356196

# %%
arr_of_torque = []
for i in df['torque']:
    if pd.notna(i):
        torque_without_units = float(i[:i.index(' ')])
        arr_of_torque.append(torque_without_units)
    else:
        arr_of_torque.append(i)

df['torque'] = arr_of_torque

# %%
# Sorry, should have made a function for most of the last cells! (too lazy now)
df = df[["price", "savings_amount", "make_name", "model_name", "year", "mileage", "body_type", "engine_displacement", "engine_type", "horsepower", "torque", "transmission", "wheel_system", "wheelbase", "fuel_type", "fuel_tank_volume", "height", "length", "width", "back_legroom", "front_legroom", "listing_color",  "major_options", "major_options_number", "maximum_seating", "city", "latitude", "longitude", "daysonmarket", "listed_date", "franchise_dealer", "seller_rating"]]
df.head()
# Out:
#                      price  savings_amount   make_name         model_name  \
# vin
# ZACNJABB5KPJ92081  23141.0               0        Jeep           Renegade
# SALCJ2FX1LH858117  46500.0               0  Land Rover    Discovery Sport
# SALRR2RV0L2433391  67430.0               0  Land Rover          Discovery
# SALCJ2FXXLH862327  48880.0               0  Land Rover    Discovery Sport
# SALYK2EX1LA261711  66903.0               0  Land Rover  Range Rover Velar
#
#                    year  mileage        body_type  engine_displacement  \
# vin
# ZACNJABB5KPJ92081  2019      7.0  SUV / Crossover               1300.0
# SALCJ2FX1LH858117  2020      8.0  SUV / Crossover               2000.0
# SALRR2RV0L2433391  2020     11.0  SUV / Crossover               3000.0
# SALCJ2FXXLH862327  2020      7.0  SUV / Crossover               2000.0
# SALYK2EX1LA261711  2020     12.0  SUV / Crossover               2000.0
#
#                   engine_type  horsepower  torque transmission wheel_system  \
# ...

# %%
len(df.index) # number of remaining observations
# Out:
# 2534281

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2534281 entries, ZACNJABB5KPJ92081 to JN8AT2MT1HW400805
# Data columns (total 32 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   price                 float64
#  1   savings_amount        int64
#  2   make_name             object
#  3   model_name            object
#  4   year                  int64
#  5   mileage               float64
#  6   body_type             object
#  7   engine_displacement   float64
#  8   engine_type           object
#  9   horsepower            float64
#  10  torque                float64
#  11  transmission          object
#  12  wheel_system          object
#  13  wheelbase             float64
#  14  fuel_type             object
#  15  fuel_tank_volume      float64
#  16  height                float64
#  17  length                float64
#  18  width                 float64
#  19  back_legroom          float64
#  20  front_legroom         float64
# ...

# %%
total_incomplete_rows = df.isnull().any(axis=1).sum()
total_incomplete_rows
# Out:
# 445566

# %%
df.isna().sum() # to check for number of missing values for each column
# Out:
# price                        0
# savings_amount               0
# make_name                    0
# model_name                   0
# year                         0
# mileage                      0
# body_type                   40
# engine_displacement          0
# engine_type                 34
# horsepower                   0
# torque                  308989
# transmission                 0
# wheel_system                 0
# wheelbase                    0
# fuel_type                    0
# fuel_tank_volume             0
# height                       0
# length                       0
# width                        0
# back_legroom                 0
# front_legroom                0
# listing_color                0
# major_options           129880
# major_options_number         0
# maximum_seating              0
# city                         0
# latitude                     0
# longitude                    0
# daysonmarket                 0
# listed_date                  0
# ...

# %%
df.drop("torque", axis=1, inplace=True)
df.drop("major_options", axis=1, inplace=True) 

df = df[df['body_type'].notna()]
df = df[df['engine_type'].notna()]
df = df[df['seller_rating'].notna()]

df.isna().sum()
# Out:
# price                   0
# savings_amount          0
# make_name               0
# model_name              0
# year                    0
# mileage                 0
# body_type               0
# engine_displacement     0
# engine_type             0
# horsepower              0
# transmission            0
# wheel_system            0
# wheelbase               0
# fuel_type               0
# fuel_tank_volume        0
# height                  0
# length                  0
# width                   0
# back_legroom            0
# front_legroom           0
# listing_color           0
# major_options_number    0
# maximum_seating         0
# city                    0
# latitude                0
# longitude               0
# daysonmarket            0
# listed_date             0
# franchise_dealer        0
# seller_rating           0
# dtype: int64

# %%
len(df.index)
# Out:
# 2500821

# %%
df['body_type'].value_counts()
# Out:
# SUV / Crossover    1237885
# Sedan               657309
# Pickup Truck        357103
# Minivan              72449
# Hatchback            70124
# Coupe                51140
# Wagon                32493
# Convertible          13055
# Van                   9263
# Name: body_type, dtype: int64

# %%
df['engine_type'].value_counts() # should delete the fuel type
# Out:
# I4                           1254124
# V6                            639965
# V8                            226659
# I4 Hybrid                      63515
# H4                             60730
# V8 Flex Fuel Vehicle           59392
# V6 Flex Fuel Vehicle           51927
# I3                             46788
# I6                             24943
# I6 Diesel                      19463
# V8 Biodiesel                   16951
# I4 Flex Fuel Vehicle            8153
# I4 Diesel                       6528
# I5                              4777
# V8 Diesel                       4472
# V6 Biodiesel                    3300
# V6 Hybrid                       2501
# V6 Diesel                       2385
# H6                              1538
# I2                               872
# V12                              603
# W12                              430
# V10                              363
# V8 Hybrid                        116
# H4 Hybrid                         89
# ...

# %%
arr_of_engine_type = []
for i in df['engine_type']:
    if " " in i:
        engine_type_without_fuel_type = str(i[:i.index(' ')])
        arr_of_engine_type.append(engine_type_without_fuel_type)
    else:
        arr_of_engine_type.append(i)

df['engine_type'] = arr_of_engine_type

df['engine_type'].value_counts()
# Out:
# I4     1332362
# V6      700080
# V8      307617
# H4       60819
# I3       46788
# I6       44422
# I5        4812
# H6        1538
# I2         872
# V12        603
# W12        496
# V10        365
# R2          44
# W8           3
# Name: engine_type, dtype: int64

# %%
df['fuel_type'].value_counts()
# Out:
# Gasoline                  2261839
# Flex Fuel Vehicle          119538
# Hybrid                      66237
# Diesel                      32852
# Biodiesel                   20284
# Compressed Natural Gas         68
# Propane                         3
# Name: fuel_type, dtype: int64

# %%
df['transmission'].value_counts()
# Out:
# A              2040679
# CVT             413270
# M                37895
# Dual Clutch       8977
# Name: transmission, dtype: int64

# %%
df['wheel_system'].value_counts()
# Out:
# FWD    1127651
# AWD     630186
# 4WD     505185
# RWD     142458
# 4X2      95341
# Name: wheel_system, dtype: int64

# %%
df['listing_color'].value_counts() # issue with UNKNOWN values
# Out:
# WHITE      520820
# BLACK      501760
# SILVER     333814
# UNKNOWN    330900
# GRAY       323235
# RED        212472
# BLUE       212070
# GREEN       19660
# BROWN       18815
# ORANGE       9376
# GOLD         8806
# TEAL         4651
# YELLOW       3088
# PURPLE       1258
# PINK           96
# Name: listing_color, dtype: int64

# %%
# Create age variable
df['age'] = [int(x[:4])-y for x,y in zip(df['listed_date'],df['year'])]

# %%
# Create vintage variable
df['vintage'] = 0
df.loc[(df['age'] > 20) & (df['body_type'].isin(['Coupe','Hatchback','SUV / Crossover'])) & (df['transmission'] == 'M'), 'vintage'] = 1
df.head()
# Out:
#                      price  savings_amount   make_name         model_name  \
# vin
# ZACNJABB5KPJ92081  23141.0               0        Jeep           Renegade
# SALCJ2FX1LH858117  46500.0               0  Land Rover    Discovery Sport
# SALRR2RV0L2433391  67430.0               0  Land Rover          Discovery
# SALCJ2FXXLH862327  48880.0               0  Land Rover    Discovery Sport
# SALYK2EX1LA261711  66903.0               0  Land Rover  Range Rover Velar
#
#                    year  mileage        body_type  engine_displacement  \
# vin
# ZACNJABB5KPJ92081  2019      7.0  SUV / Crossover               1300.0
# SALCJ2FX1LH858117  2020      8.0  SUV / Crossover               2000.0
# SALRR2RV0L2433391  2020     11.0  SUV / Crossover               3000.0
# SALCJ2FXXLH862327  2020      7.0  SUV / Crossover               2000.0
# SALYK2EX1LA261711  2020     12.0  SUV / Crossover               2000.0
#
#                   engine_type  horsepower transmission wheel_system  \
# vin
# ...

# %%
# Check if vintage variable worked
df.loc[(df['vintage'] == 1)].head(10)
# Out:
#                      price  savings_amount  make_name    model_name  year  \
# vin
# JT1VHZJ7308000038  54750.0               0     Toyota  Land Cruiser  1990
# 1J4FY19P7RP400175  18995.0               0       Jeep      Wrangler  1994
# 1J4FY29P0WP752936   5995.0               0       Jeep      Wrangler  1998
# 2G1FP22P1R2219517  15990.0               0  Chevrolet        Camaro  1994
# 1HGEJ8148XL033454   2295.0               0      Honda   Civic Coupe  1999
# WBAEC7401H0608005  27900.0               0        BMW      6 Series  1987
# 1J4FY29P0VP443109   9495.0               0       Jeep      Wrangler  1997
# JB3XE74C3MY014982  32500.0               0      Dodge       Stealth  1991
# YS3AK35E5N7005562   4995.0               0       Saab           900  1992
# 2G1FP22P9V2152224  29900.0               0  Chevrolet        Camaro  1997
#
#                     mileage        body_type  engine_displacement engine_type  \
# vin
# ...

# %%
# Create dummies for body_type
df['body_type_dum'] = df['body_type']
df = pd.get_dummies(df,'body_type',columns=["body_type_dum"])

# %%
# Make a copy of all original colums to avoid droping the column when creating dummies
df['engine_type_dum'] = df['engine_type']
df['fuel_type_dum'] = df['fuel_type']
df['transmission_dum'] = df['transmission']

# Create dummies for engine_type, fuel_type, transmission
df = pd.get_dummies(df,'engine_type',columns=["engine_type_dum"])
df = pd.get_dummies(df,'fuel_type',columns=["fuel_type_dum"])
df = pd.get_dummies(df,'transmission',columns=["transmission_dum"])

df.head(10)
# Out:
#                      price  savings_amount   make_name          model_name  \
# vin
# ZACNJABB5KPJ92081  23141.0               0        Jeep            Renegade
# SALCJ2FX1LH858117  46500.0               0  Land Rover     Discovery Sport
# SALRR2RV0L2433391  67430.0               0  Land Rover           Discovery
# SALCJ2FXXLH862327  48880.0               0  Land Rover     Discovery Sport
# SALYK2EX1LA261711  66903.0               0  Land Rover   Range Rover Velar
# 3MZBPABL6KM107908  23695.0               0       Mazda              MAZDA3
# SALYK2EX5LA275434  68520.0               0  Land Rover   Range Rover Velar
# SALCJ2FX6LH858128  51245.0               0  Land Rover     Discovery Sport
# SALZL2GX4LH007593  84399.0               0  Land Rover  Range Rover Evoque
# SALZJ2FX0LH081763  51885.0               0  Land Rover  Range Rover Evoque
#
#                    year  mileage        body_type  engine_displacement  \
# vin
# ...

# %%
# UPDATES
# Removed all observations that had NaN values for the main variables + wheelbase variable
# Main variables =  price, make_name, model_name, year, mileage, body_type, engine_displacement, horsepower, transmission, wheel_system, fuel_type
# Removed all observations that had '--' values for the variables that needed its values to not display the units and change data type
# Main variables presented no '--' values
# Changed data types of values and removed units for required variables (torque,wheelbase,fuel_tank_volume,height,length,width,front_legroom,back_legroom,maximum_seating)
# fuel_tank_volume,height,length,width,front_legroom,back_legroom,maximum_seating presented no NaN values
# Left missing values for torque as NaN because they were 12% of the remaining data 
# Added major_options_number variable to represent the amount of major options per each car (observations with NaN values were just given the value of 0)
# Arranged the colums so that related columns are next to each other, price variables are first, followed by vehicle specifications and then aspects of the sale

# SUGGESTION
# Delete savings_amount since there is no variable explanation and, thus, we cannot use it with certainty

# UPDATE 2
# Removed around 30k observations with NaN values for engine_type, body_type, and seller_rating
# Dropped torque (cuz of +300k observations with NaN values) and major_options columns (cuz of more relevant engineered feature major_options_number )
# Kept savings_amount column despite lack of variable explanation given the variable coefficient obtained from running Konstantinos' model
# Checked for other type of missing values (such as '--') in each column
# Fixed values in engine_type column which included fuel_type information for some cars
# Remaining observations = +2.5 million (prior number of observations = +2.533 million)
# Created dummy variables for vintage, body_type, engine_type, fuel_type, and transmission while keeping the original variables.

# ISSUES 
# listing_color has +330k observations with value = UNKNOWN --> limitation: lack of data might have caused the coefficient to be statistically insignificant, should collect more data and re-run the models to see true effect of variable on price

df.to_csv("vehicles_clean2.csv")
